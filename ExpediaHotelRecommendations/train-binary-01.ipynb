-- %%
require 'torch';
require 'nn';
require 'cutorch';
require 'cunn';
require 'cudnn';

-- %% [markdown]
-- ### Split data

-- %%
function split(str, pat)
   local t = {}  -- NOTE: use {n = 0} in Lua-5.0
   local fpat = "(.-)" .. pat
   local last_end = 1
   local s, e, cap = str:find(fpat, 1)
   while s do
      if s ~= 1 or cap ~= "" then
         table.insert(t,cap)
      end
      last_end = e+1
      s, e, cap = str:find(fpat, last_end)
   end
   if last_end <= #str then
      cap = str:sub(last_end)
      table.insert(t, cap)
   end
   return t
end

-- %% [markdown]
-- ## Conver Data

-- %% [markdown]
-- ### 1. To get week number

-- %%
function getYearBeginDayOfWeek(tm)
  yearBegin = os.time{year=os.date("*t",tm).year,month=1,day=1}
  yearBeginDayOfWeek = tonumber(os.date("%w",yearBegin))
  -- sunday correct from 0 -> 7
  if(yearBeginDayOfWeek == 0) then yearBeginDayOfWeek = 7 end
  return yearBeginDayOfWeek
end
function getDayAdd(tm)
  yearBeginDayOfWeek = getYearBeginDayOfWeek(tm)
  if(yearBeginDayOfWeek < 5 ) then
    -- first day is week 1
    dayAdd = (yearBeginDayOfWeek - 2)
  else 
    -- first day is week 52 or 53
    dayAdd = (yearBeginDayOfWeek - 9)
  end  
  return dayAdd
end
function getWeekNumberOfYear(tm)
  dayOfYear = os.date("%j",tm)
  dayAdd = getDayAdd(tm)
  dayOfYearCorrected = dayOfYear + dayAdd
  if(dayOfYearCorrected < 0) then
    -- week of last year - decide if 52 or 53
    lastYearBegin = os.time{year=os.date("*t",tm).year-1,month=1,day=1}
    lastYearEnd = os.time{year=os.date("*t",tm).year-1,month=12,day=31}
    dayAdd = getDayAdd(lastYearBegin)
    dayOfYear = dayOfYear + os.date("%j",lastYearEnd)
    dayOfYearCorrected = dayOfYear + dayAdd
  end  
  weekNum = math.floor((dayOfYearCorrected) / 7) + 1
  if( (dayOfYearCorrected > 0) and weekNum == 53) then
    -- check if it is not considered as part of week 1 of next year
    nextYearBegin = os.time{year=os.date("*t",tm).year+1,month=1,day=1}
    yearBeginDayOfWeek = getYearBeginDayOfWeek(nextYearBegin)
    if(yearBeginDayOfWeek < 5 ) then
      weekNum = 1
    end  
  end  
  return weekNum
end

-- %%
function __getWeekday(tm)
    return os.date("*t",tm).wday
end

-- %%
function getWeekday(input)
    dates = split(input, "-")
    if table.getn(dates) ~= 3 then
        return -1
    end
    useDate = os.time{year=dates[1],month=dates[2],day=dates[3]}
    return __getWeekday(useDate)
end

-- %%
function getLengthStay(checkin, checkout)
    local dIn= split(checkin, "-")
    local dOut= split(checkout, "-")
    if table.getn(dIn) ~= 3 or table.getn(dOut) ~= 3 then
        return -1
    end
    local useDateIn = os.time{year=dIn[1],month=dIn[2],day=dIn[3]}
    local useDateOut = os.time{year=dOut[1],month=dOut[2],day=dOut[3]}
    local days = (useDateOut - useDateIn)/(24*60*60)
    if days > 30 then
        days = 30
    end
    return days
end

-- %%
function isIncludeWeekend(checkin, checkout)
    local dIn= split(checkin, "-")
    local dOut= split(checkout, "-")
    if table.getn(dIn) ~= 3 or table.getn(dOut) ~= 3 then
        return -1
    end
    if getLengthStay(checkin, checkout) > 7 then
        return 1
    end
    local useDateIn = os.time{year=dIn[1],month=dIn[2],day=dIn[3]}
    local useDateOut = os.time{year=dOut[1],month=dOut[2],day=dOut[3]}
    date = useDateIn
    while date < useDateOut do
        if __getWeekday(date) == 6 or __getWeekday(date) == 7 then return 1 end
        date = date + 24 * 60 * 60
    end
    return 0
end

-- %%
print(isIncludeWeekend("2016-05-20", "2016-05-21"))

-- %%
function getDate(input)
    dates = split(input, "-")
    if table.getn(dates) ~= 3 then
        return -1
    end
    useDate = os.time{year=dates[1],month=dates[2],day=dates[3]}
    weekNum = getWeekNumberOfYear(useDate)
    return weekNum
end

-- %% [markdown]
-- ### 2. onehot

-- %%
function onehot(tab, value, len)
    if value == nil then
        value = 0
    end
    for i=1,len do
        if i==tonumber(value) then
            table.insert(tab, 1)
        else
            table.insert(tab, 0)
        end
    end
end

-- %%
function onehot_range(data, value, len, step)
    if value == nil then
        value = 0
    end
    for i=1,len do
        if tonumber(value) > i*tonumber(step) then
            table.insert(data, 0)
        else
            table.insert(data, 1)
            value = len * (step + 1)
        end
    end
end

-- %% [markdown]
-- ### 3. binary

-- %%
function binary(data, value, len)
    while len > 0 do
        if value % 2 == 1 then
            table.insert(data, 1)
        else
            table.insert(data, 0)
        end
        value = value / 2
        len = (len / 2) - (len / 2)%1
    end
end

-- %% [markdown]
-- ### 4. dest info

-- %%
fileName = 'data/destinations.csv'

info_sum = {}
info_mean = {}
info_std = {}
N = 1
head = 1
for i=1,149 do table.insert(info_sum, 0) end
for line in io.lines ( fileName ) do 
    if head == 1 then
        head = 0
    else
        destdata = split(line, ',')
        for j=1,149 do
            info_sum[j] = info_sum[j] + tonumber(destdata[j+1])
        end
        N = N + 1
    end
end

for i=1,149 do info_mean[i] = info_sum[i] / N end

info_sum = {}
N = 1
head = 1
for i=1,149 do table.insert(info_sum, 0) end
for line in io.lines ( fileName ) do 
    if head == 1 then
        head = 0
    else
        destdata = split(line, ',')
        for j=1,149 do
            info_sum[j] = info_sum[j] + (tonumber(destdata[j+1]) - info_mean[j]) * (tonumber(destdata[j+1]) - info_mean[j])
        end
        N = N + 1
    end
end

for i=1,149 do info_std[i] = math.sqrt(info_sum[i] / N) end

-- %%
destInfo = {}
i = 0
head = 1
nEmpty = 0
empty_row = {}
for j=1,149 do
    table.insert(empty_row, 0)
end
for line in io.lines ( fileName ) do 
    if head == 1 then
        head = 0
    else
        destdata = split(line, ',')
        while tonumber(destdata[1]) ~= i do
            --print('Empty line => destdata[1]: ' .. destdata[1], 'i: ' .. i)
            table.insert(destInfo, empty_row)
            i = i + 1
            nEmpty = nEmpty + 1
        end
        row = {}
        for j=1,149 do
            table.insert(row, (destdata[j+1] - info_mean[j]) / info_std[j])
        end
        table.insert(destInfo, row)
        if tonumber(destdata[1]) ~= i then
            --print('Not Matched => destdata[1]: ' .. destdata[1], 'i: ' .. i)
        end
        i = i + 1
    end
end

for i=1,1000 do table.insert(destInfo, empty_row) end
print('nEmpty:' .. nEmpty)
-- Out:
-- nEmpty:2888

-- %%
function addDestinationInfo(data, value)
    for i=1,149 do
        table.insert(data, destInfo[value][i])
    end
end

-- %% [markdown]
-- ### Data normalize

-- %%
distMean = 0
distsum = 0
data = loadData(1000)
N = 0
for i=1,1000 do 
    if data[i][4] ~= 0 then 
        N = N + 1; distsum = distsum + data[i][4] 
    end 
end
distMean = distsum / N
print(distsum)
print(distMean)
distsum = 0
for i=1,1000 do 
    if data[i][4] ~= 0 then 
        N = N + 1; distsum = distsum + (data[i][4] -distMean)*(data[i][4] -distMean)
    end 
end
print(math.sqrt(distsum / N))
-- Out:
-- [string "distMean = 0..."]:3: attempt to call global 'loadData' (a nil value)
-- stack traceback:
-- 	[string "distMean = 0..."]:3: in main chunk
-- 	[C]: in function 'xpcall'
-- 	/root/torch/install/share/lua/5.1/itorch/main.lua:179: in function </root/torch/install/share/lua/5.1/itorch/main.lua:143>
-- 	/root/torch/install/share/lua/5.1/lzmq/poller.lua:75: in function 'poll'
-- 	/root/torch/install/share/lua/5.1/lzmq/impl/loop.lua:307: in function 'poll'
-- 	/root/torch/install/share/lua/5.1/lzmq/impl/loop.lua:325: in function 'sleep_ex'
-- 	/root/torch/install/share/lua/5.1/lzmq/impl/loop.lua:370: in function 'start'
-- 	/root/torch/install/share/lua/5.1/itorch/main.lua:350: in main chunk
-- 	[C]: in function 'require'
-- 	(command line):1: in main chunk
-- 	[C]: at 0x00406670

-- %% [markdown]
-- ### Convert input to data

-- %%
function tableToOutput(dataTable, scalarTable)
   local data, scalarLabels, labels
   local quantity = #scalarTable
   local size = #dataTable[1]
   data = torch.Tensor(quantity, size)
   scalarLabels = torch.LongTensor(quantity):fill(-1111)
   for i=1,#dataTable do
      for j=1,#dataTable[1] do
         data[i][j] = dataTable[i][j]
      end
      scalarLabels[i] = scalarTable[i]
   end
   return data, scalarLabels
end

-- %%
function dataConvert(line)
    if line == nil then
        print('line is empty')
    end
    words = split(line, ",")
    data = {}
    aa = split(words[1], ' ')[1]
    table.insert(data, (tonumber(getDate(aa)) - 26) / 26) --1
    table.insert(data, (getDate(words[12]) - 26) / 26) --12
    table.insert(data, (getDate(words[13]) - 26) / 26) --13
    
    binary(data, getWeekday(aa), 7)
    table.insert(data, isIncludeWeekend(words[12], words[13]))
    binary(data, getLengthStay(words[12], words[13]), 30)
    
    if tonumber(words[7]) == nil then
        table.insert(data, 0) -- distance
    else
        table.insert(data, (tonumber(words[7]) - 1800) / 1600) -- distance
    end
    table.insert(data, words[9])
    table.insert(data, words[10])
    table.insert(data, words[20])
        
    binary(data, words[2], 54)
    binary(data, words[3], 5)
    binary(data, words[4], 240)
    binary(data, words[5], 1028)
    binary(data, words[6], 56509)
    binary(data, words[11], 11)
    binary(data, words[14], 10)
    binary(data, words[15], 10)
    binary(data, words[16], 9)
    binary(data, words[18], 10)
    binary(data, words[21], 7)
    binary(data, words[22], 213)
    binary(data, words[23], 2118)
    
    -- destination information (17)
    addDestinationInfo(data, tonumber(words[17]))
    
    return data
end

-- %%
function testdataConvert(line)
    if line == nil then
        print('line is empty')
    end
    words = split(line, ",")
    data = {}
    aa = split(words[2], ' ')[1]
    table.insert(data, (tonumber(getDate(aa)) - 26) / 26) --1
    table.insert(data, (getDate(words[13]) - 26) / 26) --12
    table.insert(data, (getDate(words[14]) - 26) / 26) --13
    
    binary(data, getWeekday(aa), 7)
    table.insert(data, isIncludeWeekend(words[13], words[14]))
    binary(data, getLengthStay(words[13], words[14]), 30)
    
    if tonumber(words[8]) == nil then
        table.insert(data, 0) -- distance
    else
        table.insert(data, (tonumber(words[8]) - 1800) / 1600) -- distance
    end
    table.insert(data, words[10])
    table.insert(data, words[11])
    table.insert(data, 1)
        
    binary(data, words[3], 54)
    binary(data, words[4], 5)
    binary(data, words[5], 240)
    binary(data, words[6], 1028)
    binary(data, words[7], 56509)
    binary(data, words[12], 11)
    binary(data, words[15], 10)
    binary(data, words[16], 10)
    binary(data, words[17], 9)
    binary(data, words[19], 10)
    binary(data, words[20], 7)
    binary(data, words[21], 213)
    binary(data, words[22], 2118)
    
    -- destination information (17)
    addDestinationInfo(data, tonumber(words[18]))
    
    return data
end

-- %% [markdown]
-- ### Build model

-- %%
model = nn.Sequential()
-- for onehot inputsize: 3871
model:add(nn.Linear(252, 1024))
model:add(nn.Threshold(0, 1e-6))
model:add(nn.ReLU())
model:add(nn.Linear(1024, 256))
model:add(nn.Threshold(0, 1e-6))
model:add(nn.ReLU())
model:add(nn.Linear(256, 100))
model:add(nn.Sigmoid())
model = model:cuda()

params, grad_params = model:getParameters()
crit = nn.CrossEntropyCriterion()
crit = crit:cuda()

-- %% [markdown]
-- model = nn.Sequential()
-- -- for onehot inputsize: 3871
-- model:add(nn.Linear(252, 1024))
-- model:add(nn.Sigmoid())
-- model:add(nn.Linear(1024, 2048))
-- model:add(nn.Sigmoid())
-- model:add(nn.Linear(2048, 4096))
-- model:add(nn.Sigmoid())
-- model:add(nn.Linear(4096, 100))
-- model = model:cuda()
--
-- params, grad_params = model:getParameters()
-- crit = nn.CrossEntropyCriterion()
-- crit = crit:cuda()

-- %% [markdown]
-- ### Load Data

-- %%
function loadData(quantity)
    dataTable = {}
    labTable = {}
    for i=1,quantity do
        local class = torch.random(0,99)
        local fname = 'data/train/train_' .. string.format( "%02d", class ) .. '.csv'
        file = io.open(fname, "r")
        picked = torch.random(1,file:seek("end")-200)
        file:seek("set", picked)
        file:read()
        table.insert(dataTable, dataConvert(file:read()))
        table.insert(labTable, class+1)
        io.close(file)
    end
    local data, label = tableToOutput(dataTable, labTable)
    return data, label
end

-- %% [markdown]
-- ### Print

-- %%
function PrintCM(idx)
  local loss = 0
  local top1 = 0
  model:evaluate()
  local x, y = loadData(1000)
  x = x:cuda()
  y = y:cuda()
  local N = y:size(1)
  local scores = model:forward(x)
  loss = loss + crit:forward(scores, y)

  local pred = scores:float()
  local _, pred_sorted = pred:sort(2, true)

  for i=1,N do
    for j=1,5 do
        if pred_sorted[i][j] == y[i] then
          top1 = top1 + (1/j)
        end
    end
  end
  print("idx: " .. idx, "loss: " .. loss, "train score: " .. top1 * 100 / N, 'label: ' .. y[1],
        'prediction: [1]' .. pred_sorted[1][1] .. ' [2]' .. pred_sorted[1][2] .. ' [3]' .. pred_sorted[1][3] .. ' [4]' .. pred_sorted[1][4] .. ' [5]' .. pred_sorted[1][5])
end

-- %% [markdown]
-- ### Check Size

-- %%
local x,y = loadData(2)
print(x:size())

-- %% [markdown]
-- ### Training

-- %%
require 'optim';
-- Out:
--    2
--  252
-- [torch.LongStorage of size 2]

-- %%
opt = {}
batch_size = 10000
train_size = 3000000
max_epoch = 100
opt.learningRate = 1e-2
opt.lr_decay_factor = 0.5
opt.lr_decay_every = 5 * train_size / batch_size
opt.print_every = 5
evaluate_every = 10 * train_size / batch_size
optim_config = {learningRate = opt.learningRate}
num_iterations = max_epoch * train_size / batch_size
epoch = 1

-- %%
opt.learningRate = 1e-2
opt.print_every = 5
num_iterations = max_epoch * train_size / batch_size

-- %%
-- Loss function that we pass to an optim method
function f(w)
  assert(w == params)
  grad_params:zero()

  --local x, y = loader:nextBatch('train')
  local x, y = loadData(batch_size)
  
  x = x:cuda()
  y = y:cuda()
  local scores = model:forward(x)
  local loss = crit:forward(scores, y)
  local grad_scores = crit:backward(scores, y)
  model:backward(x, grad_scores)

  grad_params:clamp(-5, 5)

  return loss, grad_params
end

-- %%
model:training()

-- %%
function saveModel(e)
    local filename = string.format("model/model_%02d.t7", e)
    model:clearState()
    model:float()
    torch.save(filename, model)
    model:cuda()
end

-- %%
function make_submission(idx)
    model:evaluate()
    testname = 'data/test.csv'
    submission_name = string.format("data/submission_%02d.csv", idx)
    submission_file = io.open(submission_name, 'w')
    head = 1
    idx = 0
    submission_file:write("id,hotel_cluster\n")
    for line in io.lines ( testname ) do
        if head == 1 then
            head = 0
        else
            testdata = testdataConvert(line)
            words = split(line, ',')
            if tonumber(words[1]) ~= idx then
                print('words:' .. words[1] .. ', idx:' .. idx)            
                idx = words[1]
            end
            tx, _ = tableToOutput({testdata}, {1})
            local outputs = model:forward(tx:cuda())
            local _, ps = outputs:float():sort(2, true)
            submission_file:write(idx .. ',' .. ps[1][1]-1 .. ' ' .. ps[1][2]-1 .. ' ' .. ps[1][3]-1 .. ' ' .. ps[1][4]-1 .. ' ' .. ps[1][5]-1 .. '\n')
            idx = idx + 1
        end
    end
    io.close(submission_file)
end

-- %%
for i = 0, num_iterations do
    if i ~= 0 and i % opt.lr_decay_every == 0 then
        old_lr = opt.learningRate
        opt.learningRate = opt.learningRate * opt.lr_decay_factor
        optim_config = {learningRate = old_lr * opt.lr_decay_factor}
        saveModel(epoch)
        epoch = epoch + 1
        print('current LR: ' .. opt.learningRate)
    end
    
    local _, loss = optim.adam(f, params, optim_config)
    if i % opt.print_every == 0 then
        model:evaluate()
        PrintCM(i)
        model:training()
    end
    
    if i ~= 0 and i % evaluate_every == 0 then
        make_submission(i)
    end
end
-- Out:
-- idx: 0	loss: 4.5759258270264	train score: 2.5783333333333	label: 15	prediction: [1]97 [2]11 [3]16 [4]30 [5]45
-- idx: 5	loss: 4.3871994018555	train score: 9.5166666666667	label: 78	prediction: [1]33 [2]4 [3]90 [4]8 [5]15
-- idx: 10	loss: 4.3011722564697	train score: 10.123333333333	label: 99	prediction: [1]8 [2]73 [3]95 [4]51 [5]48
-- idx: 15	loss: 4.2830648422241	train score: 9.545	label: 67	prediction: [1]88 [2]53 [3]66 [4]67 [5]32
-- idx: 20	loss: 4.2430720329285	train score: 11.423333333333	label: 64	prediction: [1]66 [2]88 [3]67 [4]97 [5]53
-- idx: 25	loss: 4.2296500205994	train score: 10.84	label: 72	prediction: [1]25 [2]89 [3]72 [4]80 [5]55
-- idx: 30	loss: 4.2308731079102	train score: 11.355	label: 71	prediction: [1]29 [2]78 [3]14 [4]7 [5]95
-- idx: 35	loss: 4.2138152122498	train score: 12.39	label: 80	prediction: [1]2 [2]20 [3]25 [4]80 [5]52
-- idx: 40	loss: 4.20893907547	train score: 12.683333333333	label: 50	prediction: [1]14 [2]48 [3]29 [4]51 [5]33
-- idx: 45	loss: 4.1942830085754	train score: 12.196666666667	label: 24	prediction: [1]26 [2]96 [3]69 [4]34 [5]3
-- idx: 50	loss: 4.1553030014038	train score: 12.893333333333	label: 62	prediction: [1]11 [2]91 [3]94 [4]16 [5]52
-- idx: 55	loss: 4.184947013855	train score: 13.171666666667	label: 30	prediction: [1]97 [2]35 [3]85 [4]95 [5]32
-- idx: 60	loss: 4.1706562042236	train score: 12.606666666667	label: 36	prediction: [1]21 [2]9 [3]65 [4]30 [5]31
-- idx: 65	loss: 4.1695442199707	train score: 13.565	label: 67	prediction: [1]97 [2]1 [3]67 [4]13 [5]88
-- idx: 70	loss: 4.1498847007751	train score: 13.425	label: 11	prediction: [1]29 [2]92 [3]95 [4]33 [5]17
-- idx: 75	loss: 4.1474652290344	train score: 14.373333333333	label: 94	prediction: [1]8 [2]16 [3]95 [4]33 [5]29
-- idx: 80	loss: 4.1451997756958	train score: 12.491666666667	label: 81	prediction: [1]58 [2]68 [3]21 [4]79 [5]31
-- idx: 85	loss: 4.1497392654419	train score: 12.643333333333	label: 80	prediction: [1]89 [2]85 [3]46 [4]20 [5]25
-- idx: 90	loss: 4.136643409729	train score: 12.966666666667	label: 10	prediction: [1]99 [2]69 [3]98 [4]70 [5]96
-- idx: 95	loss: 4.1419515609741	train score: 13.6	label: 24	prediction: [1]33 [2]92 [3]51 [4]73 [5]49
-- idx: 100	loss: 4.1555285453796	train score: 13.868333333333	label: 55	prediction: [1]55 [2]80 [3]95 [4]35 [5]49
-- idx: 105	loss: 4.1379547119141	train score: 13.813333333333	label: 5	prediction: [1]73 [2]19 [3]29 [4]34 [5]78
-- idx: 110	loss: 4.1139578819275	train score: 14.788333333333	label: 24	prediction: [1]73 [2]38 [3]19 [4]14 [5]26
-- idx: 115	loss: 4.1478748321533	train score: 13.693333333333	label: 76	prediction: [1]90 [2]27 [3]32 [4]53 [5]93
-- idx: 120	loss: 4.124520778656	train score: 14.791666666667	label: 30	prediction: [1]47 [2]12 [3]30 [4]31 [5]86
-- idx: 125	loss: 4.0990133285522	train score: 14.753333333333	label: 16	prediction: [1]44 [2]15 [3]8 [4]41 [5]95
-- idx: 130	loss: 4.1234984397888	train score: 15.07	label: 60	prediction: [1]7 [2]49 [3]51 [4]78 [5]19
-- idx: 135	loss: 4.1125783920288	train score: 14.006666666667	label: 2	prediction: [1]25 [2]46 [3]89 [4]80 [5]50
-- idx: 140	loss: 4.1217451095581	train score: 14.29	label: 94	prediction: [1]31 [2]59 [3]21 [4]63 [5]62
-- idx: 145	loss: 4.1312990188599	train score: 14.025	label: 7	prediction: [1]41 [2]73 [3]56 [4]18 [5]7
-- idx: 150	loss: 4.1120767593384	train score: 14.101666666667	label: 41	prediction: [1]8 [2]33 [3]51 [4]44 [5]48
-- idx: 155	loss: 4.1102910041809	train score: 13.94	label: 49	prediction: [1]48 [2]73 [3]33 [4]40 [5]43
-- idx: 160	loss: 4.0856561660767	train score: 15.655	label: 15	prediction: [1]33 [2]51 [3]40 [4]36 [5]15
-- idx: 165	loss: 4.1010761260986	train score: 15.885	label: 37	prediction: [1]13 [2]12 [3]22 [4]30 [5]37
-- idx: 170	loss: 4.1108946800232	train score: 14.998333333333	label: 13	prediction: [1]45 [2]62 [3]21 [4]63 [5]79
-- idx: 175	loss: 4.1077256202698	train score: 13.998333333333	label: 19	prediction: [1]51 [2]92 [3]33 [4]17 [5]41
-- idx: 180	loss: 4.0939044952393	train score: 17.038333333333	label: 30	prediction: [1]59 [2]79 [3]31 [4]45 [5]21
-- idx: 185	loss: 4.1134815216064	train score: 14.625	label: 52	prediction: [1]51 [2]40 [3]49 [4]77 [5]43
-- idx: 190	loss: 4.1008138656616	train score: 13.611666666667	label: 75	prediction: [1]75 [2]28 [3]92 [4]51 [5]40
-- idx: 195	loss: 4.0903272628784	train score: 16.351666666667	label: 43	prediction: [1]14 [2]51 [3]34 [4]41 [5]48
-- idx: 200	loss: 4.0843329429626	train score: 15.541666666667	label: 31	prediction: [1]86 [2]63 [3]79 [4]37 [5]59
-- idx: 205	loss: 4.1015419960022	train score: 12.985	label: 36	prediction: [1]4 [2]61 [3]60 [4]44 [5]77
-- idx: 210	loss: 4.1022486686707	train score: 13.681666666667	label: 57	prediction: [1]56 [2]98 [3]99 [4]42 [5]70
-- idx: 215	loss: 4.0824108123779	train score: 16.236666666667	label: 15	prediction: [1]68 [2]44 [3]79 [4]30 [5]31
-- idx: 220	loss: 4.0885825157166	train score: 14.983333333333	label: 68	prediction: [1]59 [2]30 [3]45 [4]3 [5]47
-- idx: 225	loss: 4.0723786354065	train score: 16.845	label: 80	prediction: [1]72 [2]46 [3]89 [4]2 [5]25
-- idx: 230	loss: 4.0927181243896	train score: 15.333333333333	label: 50	prediction: [1]22 [2]56 [3]73 [4]18 [5]20
-- idx: 235	loss: 4.0928554534912	train score: 14.278333333333	label: 61	prediction: [1]59 [2]30 [3]31 [4]62 [5]12
-- idx: 240	loss: 4.0825710296631	train score: 16.171666666667	label: 87	prediction: [1]59 [2]87 [3]9 [4]23 [5]36
-- idx: 245	loss: 4.0821743011475	train score: 15.08	label: 84	prediction: [1]73 [2]29 [3]69 [4]92 [5]10
-- idx: 250	loss: 4.0728306770325	train score: 15.618333333333	label: 21	prediction: [1]9 [2]62 [3]100 [4]79 [5]82
-- idx: 255	loss: 4.0608806610107	train score: 14.376666666667	label: 94	prediction: [1]8 [2]33 [3]43 [4]49 [5]48
-- idx: 260	loss: 4.076012134552	train score: 15.181666666667	label: 14	prediction: [1]5 [2]27 [3]32 [4]73 [5]20
-- idx: 265	loss: 4.0643405914307	train score: 17.063333333333	label: 45	prediction: [1]94 [2]45 [3]31 [4]63 [5]21
-- idx: 270	loss: 4.1096434593201	train score: 16.321666666667	label: 1	prediction: [1]85 [2]35 [3]14 [4]1 [5]74
-- idx: 275	loss: 4.089916229248	train score: 15.385	label: 33	prediction: [1]40 [2]33 [3]44 [4]41 [5]77
-- idx: 280	loss: 4.0823411941528	train score: 14.56	label: 65	prediction: [1]62 [2]86 [3]82 [4]63 [5]13
-- idx: 285	loss: 4.064236164093	train score: 13.873333333333	label: 34	prediction: [1]12 [2]69 [3]70 [4]26 [5]98
-- idx: 290	loss: 4.0663137435913	train score: 17.38	label: 61	prediction: [1]9 [2]36 [3]63 [4]87 [5]23
-- idx: 295	loss: 4.0845031738281	train score: 16.083333333333	label: 63	prediction: [1]63 [2]31 [3]79 [4]59 [5]83
-- idx: 300	loss: 4.0749106407166	train score: 16.088333333333	label: 29	prediction: [1]24 [2]48 [3]19 [4]52 [5]51
-- idx: 305	loss: 4.0808987617493	train score: 14.751666666667	label: 97	prediction: [1]88 [2]66 [3]53 [4]32 [5]97
-- idx: 310	loss: 4.0877771377563	train score: 14.208333333333	label: 6	prediction: [1]79 [2]37 [3]82 [4]100 [5]30
-- idx: 315	loss: 4.066047668457	train score: 16.028333333333	label: 60	prediction: [1]10 [2]22 [3]20 [4]19 [5]71
-- idx: 320	loss: 4.0767846107483	train score: 15.401666666667	label: 39	prediction: [1]30 [2]62 [3]86 [4]31 [5]58
-- idx: 325	loss: 4.0660262107849	train score: 16.885	label: 91	prediction: [1]34 [2]19 [3]7 [4]69 [5]43
-- idx: 330	loss: 4.0479116439819	train score: 16.228333333333	label: 88	prediction: [1]84 [2]78 [3]32 [4]38 [5]18
-- idx: 335	loss: 4.0690560340881	train score: 15.03	label: 17	prediction: [1]24 [2]1 [3]97 [4]85 [5]80
-- idx: 340	loss: 4.0853667259216	train score: 13.678333333333	label: 64	prediction: [1]21 [2]64 [3]45 [4]79 [5]58
-- idx: 345	loss: 4.0582060813904	train score: 15.276666666667	label: 37	prediction: [1]31 [2]63 [3]58 [4]44 [5]21
-- idx: 350	loss: 4.0543932914734	train score: 16.323333333333	label: 19	prediction: [1]33 [2]34 [3]78 [4]95 [5]29
-- idx: 355	loss: 4.0631785392761	train score: 15.18	label: 71	prediction: [1]42 [2]22 [3]71 [4]98 [5]92
-- idx: 360	loss: 4.08518409729	train score: 15.47	label: 83	prediction: [1]26 [2]12 [3]65 [4]30 [5]6
-- idx: 365	loss: 4.0561065673828	train score: 15.551666666667	label: 8	prediction: [1]44 [2]16 [3]8 [4]15 [5]51
-- idx: 370	loss: 4.0713410377502
-- train score: 15.395	label: 41	prediction: [1]51 [2]8 [3]33 [4]77 [5]43
-- idx: 375	loss: 4.0794892311096	train score: 15.63	label: 65	prediction: [1]65 [2]12 [3]6 [4]26 [5]3
-- idx: 380	loss: 4.0816164016724	train score: 15.24	label: 28	prediction: [1]28 [2]32 [3]80 [4]11 [5]81
-- idx: 385	loss: 4.0882682800293	train score: 16.101666666667	label: 6	prediction: [1]49 [2]43 [3]95 [4]33 [5]17
-- idx: 390	loss: 4.0754914283752	train score: 16.378333333333	label: 52	prediction: [1]15 [2]49 [3]43 [4]40 [5]51
-- idx: 395	loss: 4.0728058815002	train score: 15.893333333333	label: 49	prediction: [1]41 [2]56 [3]19 [4]18 [5]84
-- idx: 400	loss: 4.0547113418579	train score: 16.061666666667	label: 39	prediction: [1]87 [2]65 [3]6 [4]12 [5]98
-- idx: 405	loss: 4.0635290145874	train score: 16.986666666667	label: 80	prediction: [1]89 [2]52 [3]85 [4]25 [5]80
-- idx: 410	loss: 4.053023815155	train score: 15.856666666667	label: 71	prediction: [1]65 [2]71 [3]34 [4]38 [5]39
-- idx: 415	loss: 4.0410070419312	train score: 17.143333333333	label: 1	prediction: [1]91 [2]45 [3]1 [4]35 [5]27
-- idx: 420	loss: 4.0716791152954	train score: 16.275	label: 20	prediction: [1]5 [2]50 [3]96 [4]14 [5]20
-- idx: 425	loss: 4.0646481513977	train score: 14.295	label: 15	prediction: [1]49 [2]95 [3]40 [4]15 [5]48
-- idx: 430	loss: 4.0590019226074	train score: 16.75	label: 16	prediction: [1]91 [2]56 [3]81 [4]74 [5]18
-- idx: 435	loss: 4.0418744087219	train score: 16.466666666667	label: 90	prediction: [1]53 [2]76 [3]66 [4]61 [5]97
-- idx: 440	loss: 4.052848815918	train score: 16.115	label: 60	prediction: [1]37 [2]63 [3]83 [4]79 [5]31
-- idx: 445	loss: 4.0554857254028	train score: 14.613333333333	label: 1	prediction: [1]93 [2]1 [3]85 [4]34 [5]22
-- idx: 450	loss: 4.0527052879333	train score: 16.01	label: 14	prediction: [1]92 [2]49 [3]51 [4]41 [5]40
-- idx: 455	loss: 4.0804653167725	train score: 16.77	label: 3	prediction: [1]49 [2]92 [3]17 [4]33 [5]95
-- idx: 460	loss: 4.0588393211365	train score: 16.551666666667	label: 41	prediction: [1]92 [2]49 [3]33 [4]29 [5]40
-- idx: 465	loss: 4.0566172599792	train score: 17.33	label: 94	prediction: [1]34 [2]18 [3]11 [4]84 [5]38
-- idx: 470	loss: 4.0518002510071	train score: 15.351666666667	label: 68	prediction: [1]63 [2]83 [3]58 [4]16 [5]86
-- idx: 475	loss: 4.0384621620178	train score: 16.918333333333	label: 73	prediction: [1]38 [2]40 [3]92 [4]26 [5]84
-- idx: 480	loss: 4.0520777702332	train score: 16.153333333333	label: 20	prediction: [1]3 [2]20 [3]69 [4]34 [5]65
-- idx: 485	loss: 4.0422649383545	train score: 15.893333333333	label: 29	prediction: [1]92 [2]41 [3]73 [4]49 [5]24
-- idx: 490	loss: 4.0608096122742	train score: 15.015	label: 71	prediction: [1]70 [2]69 [3]19 [4]50 [5]73
-- idx: 495	loss: 4.0711274147034	train score: 14.878333333333	label: 39	prediction: [1]26 [2]59 [3]65 [4]21 [5]63
-- idx: 500	loss: 4.0564608573914	train score: 16.05	label: 95	prediction: [1]27 [2]35 [3]85 [4]97 [5]72
-- idx: 505	loss: 4.0643401145935	train score: 15.261666666667	label: 70	prediction: [1]100 [2]10 [3]22 [4]42 [5]69
-- idx: 510	loss: 4.041289806366	train score: 16.431666666667	label: 41	prediction: [1]70 [2]84 [3]71 [4]98 [5]42
-- idx: 515	loss: 4.0661125183105	train score: 16.745	label: 20	prediction: [1]24 [2]73 [3]19 [4]96 [5]99
-- idx: 520	loss: 4.0317101478577	train score: 15.923333333333	label: 45	prediction: [1]62 [2]45 [3]31 [4]63 [5]21
-- idx: 525	loss: 4.0733637809753	train score: 17.466666666667	label: 38	prediction: [1]38 [2]34 [3]42 [4]78 [5]70
-- idx: 530	loss: 4.049961566925	train score: 15.431666666667	label: 19	prediction: [1]60 [2]12 [3]77 [4]33 [5]19
-- idx: 535	loss: 4.0405383110046	train score: 16.065	label: 43	prediction: [1]94 [2]95 [3]17 [4]78 [5]15
-- idx: 540	loss: 4.0563549995422	train score: 16.3	label: 3	prediction: [1]32 [2]29 [3]20 [4]14 [5]33
-- idx: 545	loss: 4.0764136314392	train score: 17	label: 68	prediction: [1]79 [2]45 [3]31 [4]86 [5]83
-- idx: 550	loss: 4.0424828529358	train score: 16.471666666667	label: 66	prediction: [1]66 [2]81 [3]53 [4]88 [5]67
-- idx: 555	loss: 4.056245803833	train score: 16.888333333333	label: 52	prediction: [1]72 [2]89 [3]80 [4]2 [5]50
-- idx: 560	loss: 4.0618643760681	train score: 16.203333333333	label: 58	prediction: [1]63 [2]37 [3]21 [4]82 [5]30
-- idx: 565	loss: 4.048499584198	train score: 16.318333333333	label: 31	prediction: [1]31 [2]30 [3]21 [4]83 [5]59
-- idx: 570	loss: 4.0667080879211	train score: 14.063333333333	label: 7	prediction: [1]47 [2]68 [3]30 [4]83 [5]82
-- idx: 575	loss: 4.0444631576538	train score: 15.288333333333	label: 68	prediction: [1]79 [2]39 [3]45 [4]21 [5]44
-- idx: 580	loss: 4.0643887519836	train score: 15.353333333333	label: 66	prediction: [1]67 [2]32 [3]88 [4]66 [5]81
-- idx: 585	loss: 4.0640211105347	train score: 15.306666666667	label: 64	prediction: [1]31 [2]62 [3]30 [4]21 [5]59
-- idx: 590	loss: 4.0601711273193	train score: 15.933333333333	label: 15	prediction: [1]48 [2]73 [3]24 [4]15 [5]78
-- idx: 595	loss: 4.0589513778687	train score: 13.993333333333	label: 18	prediction: [1]92 [2]60 [3]19 [4]69 [5]17
-- idx: 600	loss: 4.0502781867981	train score: 16.038333333333	label: 74	prediction: [1]44 [2]33 [3]51 [4]64 [5]31
-- idx: 605	loss: 4.0542430877686	train score: 15.151666666667	label: 35	prediction: [1]26 [2]49 [3]77 [4]73 [5]22
-- idx: 610	loss: 4.0639934539795	train score: 16.473333333333	label: 73	prediction: [1]84 [2]6 [3]91 [4]15 [5]77
-- idx: 615	loss: 4.0421009063721	train score: 15.925	label: 18	prediction: [1]98 [2]70 [3]57 [4]99 [5]42
-- idx: 620	loss: 4.03484582901	train score: 15.453333333333	label: 56	prediction: [1]69 [2]57 [3]50 [4]20 [5]70
-- idx: 625	loss: 4.0572099685669	train score: 14.763333333333	label: 16	prediction: [1]45 [2]59 [3]63 [4]21 [5]62
-- idx: 630	loss: 4.0434675216675	train score: 15.055	label: 50	prediction: [1]72 [2]89 [3]80 [4]2 [5]50
-- idx: 635	loss: 4.0779938697815	train score: 15.353333333333	label: 67	prediction: [1]88 [2]66 [3]53 [4]67 [5]85
-- idx: 640	loss: 4.0625700950623	train score: 15.33	label: 59	prediction: [1]45 [2]21 [3]82 [4]64 [5]79
-- idx: 645	loss: 4.041558265686	train score: 15.101666666667	label: 91	prediction: [1]8 [2]33 [3]15 [4]95 [5]51
-- idx: 650	loss: 4.0251340866089	train score: 17.648333333333	label: 54	prediction: [1]63 [2]61 [3]21 [4]68 [5]65
-- idx: 655	loss: 4.0615677833557	train score: 15.523333333333	label: 47	prediction: [1]88 [2]45 [3]81 [4]28 [5]64
-- idx: 660	loss: 4.0603322982788	train score: 16.181666666667	label: 14	prediction: [1]94 [2]97 [3]18 [4]71 [5]91
-- idx: 665	loss: 4.0334343910217	train score: 15.155	label: 6	prediction: [1]15 [2]49 [3]43 [4]51 [5]40
-- idx: 670	loss: 4.0550384521484	train score: 14.713333333333	label: 100	prediction: [1]3 [2]94 [3]60 [4]10 [5]91
-- idx: 675	loss: 4.0565438270569	train score: 14.65	label: 19	prediction: [1]95 [2]92 [3]84 [4]73 [5]26
-- idx: 680	loss: 4.0567989349365	train score: 17.621666666667	label: 26	prediction: [1]49 [2]95 [3]48 [4]40 [5]14
-- idx: 685	loss: 4.0401005744934	train score: 15.655	label: 41	prediction: [1]19 [2]95 [3]48 [4]49 [5]52
-- idx: 690	loss: 4.0594081878662	train score: 15.353333333333	label: 8	prediction: [1]8 [2]48 [3]92 [4]51 [5]49
-- idx: 695	loss: 4.0556631088257	train score: 14.696666666667	label: 52	prediction: [1]77 [2]41 [3]94 [4]84 [5]48
-- idx: 700	loss: 4.0454411506653	train score: 16.996666666667	label: 57	prediction: [1]87 [2]22 [3]42 [4]57 [5]38
-- idx: 705	loss: 4.0424523353577	train score: 16.271666666667	label: 35	prediction: [1]11 [2]50 [3]97 [4]91 [5]76
-- idx: 710	loss: 4.0696797370911	train score: 14.781666666667	label: 61	prediction: [1]58 [2]63 [3]13 [4]59 [5]82
-- idx: 715	loss: 4.0489621162415	train score: 15.488333333333	label: 6	prediction: [1]52 [2]73 [3]29 [4]33 [5]34
-- idx: 720	loss: 4.0356435775757	train score: 15.508333333333	label: 7	prediction: [1]14 [2]60 [3]31 [4]26 [5]91
-- idx: 725	loss: 4.0682597160339	train score: 16.263333333333	label: 9	prediction: [1]34 [2]85 [3]22 [4]1 [5]57
-- idx: 730	loss: 4.0539712905884	train score: 15.543333333333	label: 10	prediction: [1]12 [2]65 [3]98 [4]70 [5]69
-- idx: 735	loss: 4.0362186431885	train score: 15.348333333333	label: 35	prediction: [1]44 [2]74 [3]18 [4]94 [5]35
-- idx: 740	loss: 4.0499262809753	train score: 16.811666666667	label: 69	prediction: [1]11 [2]10 [3]19 [4]18 [5]50
-- idx: 745	loss: 4.0449776649475	train score: 16.256666666667	label: 99	prediction: [1]56 [2]69 [3]34 [4]35 [5]38
-- idx: 750	loss: 4.0322489738464	train score: 14.401666666667	label: 49	prediction: [1]48 [2]17 [3]16 [4]15 [5]14
-- idx: 755	loss: 4.0215835571289	train score: 15.755	label: 95	prediction: [1]51 [2]49 [3]20 [4]24 [5]60
-- idx: 760	loss: 4.0349054336548	train score: 16.19	label: 63	prediction: [1]61 [2]59 [3]63 [4]62 [5]21
-- idx: 765	loss: 4.0357918739319	train score: 15.405	label: 52	prediction: [1]49 [2]15 [3]36 [4]40 [5]77
-- idx: 770	loss: 4.0568480491638	train score: 14.6	label: 82	prediction: [1]39 [2]68 [3]83 [4]31 [5]82
-- idx: 775	loss: 4.0470271110535	train score: 16.758333333333	label: 89	prediction: [1]46 [2]85 [3]89 [4]25 [5]72
-- idx: 780	loss: 4.0480828285217	train score: 15.483333333333	label: 21	prediction: [1]64 [2]44 [3]31 [4]97 [5]63
-- idx: 785	loss: 4.0577330589294	train score: 14.831666666667	label: 79	prediction: [1]39 [2]44 [3]87 [4]100 [5]36
-- idx: 790	loss: 4.0742058753967
-- train score: 13.991666666667	label: 74	prediction: [1]74 [2]91 [3]11 [4]19 [5]29
-- idx: 795	loss: 4.0318379402161	train score: 15.99	label: 19	prediction: [1]51 [2]49 [3]19 [4]52 [5]24
-- idx: 800	loss: 4.030083656311	train score: 14.215	label: 48	prediction: [1]51 [2]33 [3]43 [4]17 [5]95
-- idx: 805	loss: 4.0558524131775	train score: 14.851666666667	label: 89	prediction: [1]55 [2]50 [3]89 [4]46 [5]2
-- idx: 810	loss: 4.0538272857666	train score: 16.998333333333	label: 23	prediction: [1]10 [2]9 [3]62 [4]63 [5]65
-- idx: 815	loss: 4.0454053878784	train score: 14.385	label: 13	prediction: [1]21 [2]68 [3]58 [4]47 [5]76
-- idx: 820	loss: 4.035514831543	train score: 15.285	label: 97	prediction: [1]91 [2]18 [3]74 [4]84 [5]11
-- idx: 825	loss: 4.0504016876221	train score: 16.101666666667	label: 60	prediction: [1]26 [2]12 [3]60 [4]92 [5]19
-- idx: 830	loss: 4.0451006889343	train score: 14.253333333333	label: 81	prediction: [1]14 [2]1 [3]93 [4]81 [5]5
-- idx: 835	loss: 4.0400953292847	train score: 14.785	label: 7	prediction: [1]95 [2]77 [3]17 [4]51 [5]49
-- idx: 840	loss: 4.0508904457092	train score: 16.483333333333	label: 80	prediction: [1]2 [2]80 [3]46 [4]89 [5]85
-- idx: 845	loss: 4.0477848052979	train score: 15.516666666667	label: 59	prediction: [1]63 [2]79 [3]65 [4]31 [5]9
-- idx: 850	loss: 4.0538339614868	train score: 15.793333333333	label: 65	prediction: [1]59 [2]30 [3]65 [4]64 [5]63
-- idx: 855	loss: 4.065767288208	train score: 14.695	label: 64	prediction: [1]92 [2]49 [3]40 [4]33 [5]48
-- idx: 860	loss: 4.0399708747864	train score: 14.813333333333	label: 3	prediction: [1]62 [2]86 [3]3 [4]37 [5]91
-- idx: 865	loss: 4.0654249191284	train score: 15.66	label: 40	prediction: [1]22 [2]50 [3]97 [4]94 [5]90
-- idx: 870	loss: 4.0458507537842	train score: 15.438333333333	label: 84	prediction: [1]14 [2]100 [3]90 [4]84 [5]74
-- idx: 875	loss: 4.0394215583801	train score: 17.296666666667	label: 42	prediction: [1]70 [2]26 [3]19 [4]50 [5]22
-- idx: 880	loss: 4.0449280738831	train score: 16.93	label: 45	prediction: [1]7 [2]44 [3]19 [4]15 [5]91
-- idx: 885	loss: 4.0438370704651	train score: 15.261666666667	label: 26	prediction: [1]12 [2]90 [3]18 [4]65 [5]77
-- idx: 890	loss: 4.060133934021	train score: 14.951666666667	label: 94	prediction: [1]1 [2]74 [3]35 [4]45 [5]14
-- idx: 895	loss: 4.0334987640381	train score: 16.975	label: 74	prediction: [1]22 [2]19 [3]69 [4]60 [5]29
-- idx: 900	loss: 4.0490951538086	train score: 15.776666666667	label: 99	prediction: [1]57 [2]11 [3]78 [4]51 [5]18
-- idx: 905	loss: 4.0555272102356	train score: 17.396666666667	label: 54	prediction: [1]64 [2]45 [3]58 [4]59 [5]31
-- idx: 910	loss: 4.0431971549988	train score: 16.041666666667	label: 39	prediction: [1]44 [2]21 [3]83 [4]68 [5]39
-- idx: 915	loss: 4.0372242927551	train score: 15.311666666667	label: 58	prediction: [1]58 [2]65 [3]82 [4]21 [5]83
-- idx: 920	loss: 4.068549156189	train score: 17.693333333333	label: 53	prediction: [1]53 [2]88 [3]66 [4]67 [5]73
-- idx: 925	loss: 4.0534582138062	train score: 15.606666666667	label: 28	prediction: [1]28 [2]9 [3]95 [4]47 [5]58
-- idx: 930	loss: 4.0634388923645	train score: 17.11	label: 26	prediction: [1]84 [2]73 [3]26 [4]57 [5]22
-- idx: 935	loss: 4.0359635353088	train score: 15.573333333333	label: 54	prediction: [1]68 [2]45 [3]86 [4]82 [5]31
-- idx: 940	loss: 4.047872543335	train score: 15.22	label: 31	prediction: [1]65 [2]82 [3]62 [4]63 [5]13
-- idx: 945	loss: 4.0546584129333	train score: 15.928333333333	label: 82	prediction: [1]21 [2]58 [3]68 [4]63 [5]62
-- idx: 950	loss: 4.0536751747131	train score: 15.235	label: 95	prediction: [1]49 [2]43 [3]17 [4]24 [5]51
-- idx: 955	loss: 4.0425906181335	train score: 13.893333333333	label: 31	prediction: [1]73 [2]56 [3]60 [4]69 [5]70
-- idx: 960	loss: 4.0552201271057	train score: 16.176666666667	label: 53	prediction: [1]67 [2]88 [3]66 [4]53 [5]73
-- idx: 965	loss: 4.039333820343	train score: 13.443333333333	label: 23	prediction: [1]36 [2]51 [3]33 [4]8 [5]56
-- idx: 970	loss: 4.0520968437195	train score: 15.146666666667	label: 55	prediction: [1]42 [2]55 [3]27 [4]85 [5]72
-- idx: 975	loss: 4.0448565483093	train score: 14.866666666667	label: 95	prediction: [1]51 [2]29 [3]92 [4]49 [5]14
-- idx: 980	loss: 4.0684661865234	train score: 15.331666666667	label: 81	prediction: [1]88 [2]81 [3]53 [4]32 [5]66
-- idx: 985	loss: 4.0269637107849	train score: 16.391666666667	label: 7	prediction: [1]22 [2]73 [3]34 [4]19 [5]50
-- idx: 990	loss: 4.0403208732605	train score: 16.938333333333	label: 16	prediction: [1]83 [2]30 [3]87 [4]65 [5]31
-- idx: 995	loss: 4.0441741943359	train score: 15.563333333333	label: 63	prediction: [1]45 [2]31 [3]64 [4]37 [5]88
-- idx: 1000	loss: 4.0571084022522	train score: 15.635	label: 19	prediction: [1]73 [2]40 [3]5 [4]19 [5]50
-- idx: 1005	loss: 4.041823387146	train score: 16.025	label: 56	prediction: [1]87 [2]85 [3]35 [4]42 [5]18
-- idx: 1010	loss: 4.0380835533142	train score: 15.171666666667	label: 7	prediction: [1]52 [2]33 [3]91 [4]92 [5]17
-- idx: 1015	loss: 4.0573391914368	train score: 17.11	label: 71	prediction: [1]70 [2]42 [3]56 [4]57 [5]69
-- idx: 1020	loss: 4.0468158721924	train score: 14.841666666667	label: 82	prediction: [1]63 [2]82 [3]58 [4]13 [5]47
-- idx: 1025	loss: 4.0360798835754	train score: 14.993333333333	label: 92	prediction: [1]56 [2]71 [3]35 [4]38 [5]40
-- idx: 1030	loss: 4.0513372421265	train score: 15.931666666667	label: 92	prediction: [1]70 [2]98 [3]99 [4]81 [5]71
-- idx: 1035	loss: 4.036036491394	train score: 15.081666666667	label: 84	prediction: [1]26 [2]49 [3]69 [4]56 [5]22
-- idx: 1040	loss: 4.0519742965698	train score: 15.916666666667	label: 11	prediction: [1]51 [2]48 [3]17 [4]92 [5]61
-- idx: 1045	loss: 4.0505023002625	train score: 16.646666666667	label: 37	prediction: [1]9 [2]79 [3]39 [4]37 [5]68
-- idx: 1050	loss: 4.0633540153503	train score: 15.465	label: 4	prediction: [1]8 [2]7 [3]92 [4]15 [5]51
-- idx: 1055
-- loss: 4.0463652610779	train score: 15.786666666667	label: 57	prediction: [1]87 [2]71 [3]99 [4]42 [5]98
-- idx: 1060	loss: 4.0402774810791	train score: 14.45	label: 55	prediction: [1]55 [2]51 [3]80 [4]95 [5]75
-- idx: 1065	loss: 4.0700721740723	train score: 14.923333333333	label: 43	prediction: [1]43 [2]95 [3]49 [4]48 [5]92
-- idx: 1070	loss: 4.0291228294373	train score: 16.806666666667	label: 40	prediction: [1]92 [2]51 [3]19 [4]17 [5]16
-- idx: 1075	loss: 4.0483069419861	train score: 15.786666666667	label: 36	prediction: [1]73 [2]41 [3]95 [4]92 [5]90
-- idx: 1080	loss: 4.0250730514526	train score: 16.083333333333	label: 100	prediction: [1]13 [2]91 [3]31 [4]26 [5]65
-- idx: 1085	loss: 4.050660610199	train score: 15.243333333333	label: 25	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1090	loss: 4.0469079017639	train score: 15.156666666667	label: 74	prediction: [1]14 [2]33 [3]77 [4]92 [5]51
-- idx: 1095	loss: 4.0500102043152	train score: 13.888333333333	label: 10	prediction: [1]84 [2]69 [3]90 [4]42 [5]12
-- idx: 1100	loss: 4.0445561408997	train score: 15.055	label: 43	prediction: [1]60 [2]40 [3]17 [4]24 [5]77
-- idx: 1105	loss: 4.0457463264465	train score: 15.101666666667	label: 94	prediction: [1]62 [2]59 [3]21 [4]83 [5]86
-- idx: 1110	loss: 4.0313386917114	train score: 16.72	label: 39	prediction: [1]13 [2]39 [3]37 [4]58 [5]60
-- idx: 1115	loss: 4.057315826416	train score: 14.716666666667	label: 17	prediction: [1]43 [2]48 [3]92 [4]32 [5]33
-- idx: 1120	loss: 4.0483927726746	train score: 14.288333333333	label: 7	prediction: [1]33 [2]40 [3]92 [4]78 [5]77
-- idx: 1125	loss: 4.0388689041138	train score: 13.925	label: 32	prediction: [1]95 [2]43 [3]92 [4]15 [5]40
-- idx: 1130	loss: 4.0346584320068	train score: 15.823333333333	label: 4	prediction: [1]8 [2]49 [3]33 [4]92 [5]48
-- idx: 1135	loss: 4.0478224754333	train score: 14.25	label: 32	prediction: [1]93 [2]88 [3]27 [4]32 [5]63
-- idx: 1140	loss: 4.0281577110291	train score: 16.488333333333	label: 18	prediction: [1]69 [2]84 [3]19 [4]20 [5]22
-- idx: 1145	loss: 4.0293140411377	train score: 15.988333333333	label: 69	prediction: [1]22 [2]24 [3]50 [4]18 [5]19
-- idx: 1150	loss: 4.0388836860657	train score: 15.368333333333	label: 85	prediction: [1]93 [2]74 [3]27 [4]1 [5]35
-- idx: 1155	loss: 4.0370578765869	train score: 15.403333333333	label: 50	prediction: [1]24 [2]26 [3]19 [4]20 [5]22
-- idx: 1160	loss: 4.0471301078796	train score: 14.79	label: 77	prediction: [1]49 [2]8 [3]14 [4]40 [5]95
-- idx: 1165	loss: 4.0213785171509	train score: 14.831666666667	label: 85	prediction: [1]85 [2]35 [3]66 [4]67 [5]74
-- idx: 1170	loss: 4.0320348739624	train score: 15.635	label: 35	prediction: [1]72 [2]85 [3]32 [4]35 [5]42
-- idx: 1175	loss: 4.0263662338257	train score: 15.496666666667	label: 2	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1180	loss: 4.0373387336731	train score: 15.121666666667	label: 30	prediction: [1]86 [2]82 [3]58 [4]13 [5]37
-- idx: 1185	loss: 4.0512204170227	train score: 14.435	label: 13	prediction: [1]62 [2]64 [3]68 [4]82 [5]86
-- idx: 1190	loss: 4.0415892601013	train score: 15.933333333333	label: 85	prediction: [1]32 [2]93 [3]87 [4]27 [5]64
-- idx: 1195	loss: 4.0348353385925	train score: 16.365	label: 80	prediction: [1]72 [2]2 [3]46 [4]85 [5]20
-- idx: 1200	loss: 4.0367527008057	train score: 15.186666666667	label: 72	prediction: [1]55 [2]89 [3]20 [4]25 [5]80
-- idx: 1205
-- loss: 4.0367240905762	train score: 13.966666666667	label: 23	prediction: [1]62 [2]31 [3]79 [4]21 [5]23
-- idx: 1210	loss: 4.0418558120728	train score: 15.691666666667	label: 92	prediction: [1]48 [2]41 [3]17 [4]95 [5]19
-- idx: 1215	loss: 4.0367088317871	train score: 14.386666666667	label: 87	prediction: [1]86 [2]30 [3]68 [4]31 [5]87
-- idx: 1220	loss: 4.0218019485474	train score: 16.398333333333	label: 39	prediction: [1]16 [2]17 [3]43 [4]48 [5]77
-- idx: 1225	loss: 4.047191619873	train score: 15.475	label: 10	prediction: [1]22 [2]42 [3]18 [4]19 [5]20
-- idx: 1230	loss: 4.0517859458923	train score: 14.425	label: 5	prediction: [1]73 [2]77 [3]16 [4]17 [5]40
-- idx: 1235	loss: 4.0524082183838	train score: 14.276666666667	label: 12	prediction: [1]22 [2]40 [3]71 [4]12 [5]42
-- idx: 1240	loss: 4.0541734695435	train score: 16.09	label: 12	prediction: [1]39 [2]12 [3]26 [4]21 [5]65
-- idx: 1245	loss: 4.0246767997742	train score: 14.786666666667	label: 26	prediction: [1]37 [2]39 [3]21 [4]82 [5]30
-- idx: 1250	loss: 4.0479965209961	train score: 15.036666666667	label: 79	prediction: [1]87 [2]79 [3]45 [4]31 [5]30
-- idx: 1255	loss: 4.045618057251	train score: 15.348333333333	label: 90	prediction: [1]78 [2]24 [3]52 [4]19 [5]26
-- idx: 1260	loss: 4.0249371528625	train score: 15.361666666667	label: 47	prediction: [1]65 [2]86 [3]83 [4]37 [5]62
-- idx: 1265	loss: 4.031289100647	train score: 14.975	label: 78	prediction: [1]55 [2]78 [3]18 [4]40 [5]11
-- idx: 1270	loss: 4.0480999946594	train score: 14.885	label: 70	prediction: [1]99 [2]22 [3]98 [4]42 [5]70
-- idx: 1275	loss: 4.0342631340027	train score: 15.288333333333	label: 26	prediction: [1]69 [2]50 [3]22 [4]24 [5]26
-- idx: 1280	loss: 4.0428357124329	train score: 14.801666666667	label: 80	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1285	loss: 4.0297508239746	train score: 15.525	label: 89	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1290	loss: 4.0515270233154	train score: 16.07	label: 63	prediction: [1]79 [2]44 [3]21 [4]31 [5]83
-- idx: 1295	loss: 4.0574154853821	train score: 15.3	label: 15	prediction: [1]94 [2]8 [3]31 [4]51 [5]44
-- idx: 1300	loss: 4.0549077987671	train score: 15.83	label: 45	prediction: [1]39 [2]64 [3]83 [4]82 [5]31
-- idx: 1305	loss: 4.0555758476257	train score: 14.973333333333	label: 24	prediction: [1]87 [2]56 [3]69 [4]42 [5]70
-- idx: 1310	loss: 4.054274559021	train score: 14.495	label: 86	prediction: [1]82 [2]44 [3]86 [4]31 [5]36
-- idx: 1315	loss: 4.0479893684387	train score: 16.505	label: 33	prediction: [1]92 [2]29 [3]48 [4]77 [5]95
-- idx: 1320	loss: 4.0461158752441	train score: 15.511666666667	label: 19	prediction: [1]77 [2]40 [3]92 [4]91 [5]36
-- idx: 1325	loss: 4.0760040283203	train score: 15.731666666667	label: 40	prediction: [1]54 [2]63 [3]94 [4]31 [5]91
-- idx: 1330	loss: 4.0319566726685	train score: 16.005	label: 58	prediction: [1]69 [2]91 [3]22 [4]30 [5]38
-- idx: 1335	loss: 4.0504884719849	train score: 15.718333333333	label: 95	prediction: [1]26 [2]38 [3]20 [4]19 [5]42
-- idx: 1340	loss: 4.0446634292603	train score: 14.271666666667	label: 74	prediction: [1]45 [2]64 [3]82 [4]31 [5]39
-- idx: 1345	loss: 4.0390491485596	train score: 14.948333333333	label: 3	prediction: [1]78 [2]92 [3]14 [4]24 [5]51
-- idx: 1350	loss: 4.0547308921814	train score: 15.305	label: 51	prediction: [1]44 [2]43 [3]16 [4]17 [5]95
-- idx: 1355	loss: 4.0556101799011	train score: 14.425	label: 24	prediction: [1]49 [2]26 [3]69 [4]56 [5]52
-- idx: 1360	loss: 4.0642671585083	train score: 15.768333333333	label: 46	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1365	loss: 4.0240597724915	train score: 15.765	label: 96	prediction: [1]60 [2]40 [3]73 [4]65 [5]29
-- idx: 1370	loss: 4.0289440155029	train score: 16.991666666667	label: 64	prediction: [1]63 [2]93 [3]82 [4]37 [5]13
-- idx: 1375	loss: 4.0411777496338	train score: 15.108333333333	label: 54	prediction: [1]83 [2]63 [3]59 [4]31 [5]30
-- idx: 1380	loss: 4.0350351333618	train score: 13.798333333333	label: 67	prediction: [1]88 [2]85 [3]74 [4]35 [5]67
-- idx: 1385	loss: 4.0342645645142	train score: 15.328333333333	label: 69	prediction: [1]22 [2]38 [3]20 [4]19 [5]73
-- idx: 1390	loss: 4.0478601455688	train score: 16.138333333333	label: 82	prediction: [1]82 [2]30 [3]63 [4]22 [5]100
-- idx: 1395	loss: 4.0510768890381	train score: 14.451666666667	label: 100	prediction: [1]49 [2]51 [3]33 [4]34 [5]38
-- idx: 1400	loss: 4.0582656860352	train score: 14.261666666667	label: 96	prediction: [1]20 [2]41 [3]42 [4]18 [5]19
-- idx: 1405	loss: 4.0678086280823	train score: 14.63	label: 27
-- prediction: [1]99 [2]70 [3]98 [4]71 [5]57
-- idx: 1410	loss: 4.0272645950317	train score: 15.756666666667	label: 79	prediction: [1]1 [2]97 [3]35 [4]32 [5]55
-- idx: 1415	loss: 4.0398740768433	train score: 15.608333333333	label: 56	prediction: [1]41 [2]18 [3]69 [4]70 [5]20
-- idx: 1420	loss: 4.0429854393005	train score: 16.248333333333	label: 98	prediction: [1]26 [2]90 [3]100 [4]19 [5]63
-- idx: 1425	loss: 4.0582504272461	train score: 14.518333333333	label: 51	prediction: [1]52 [2]7 [3]11 [4]73 [5]78
-- idx: 1430	loss: 4.0360016822815	train score: 16.001666666667	label: 24	prediction: [1]22 [2]42 [3]18 [4]19 [5]20
-- idx: 1435	loss: 4.047080039978	train score: 15.146666666667	label: 75	prediction: [1]75 [2]29 [3]55 [4]28 [5]84
-- idx: 1440	loss: 4.0542478561401	train score: 15.496666666667	label: 13	prediction: [1]68 [2]65 [3]82 [4]30 [5]37
-- idx: 1445	loss: 4.0404787063599	train score: 14.568333333333	label: 84	prediction: [1]52 [2]71 [3]34 [4]38 [5]40
-- idx: 1450	loss: 4.0474834442139	train score: 17.138333333333	label: 65	prediction: [1]12 [2]69 [3]36 [4]39 [5]30
-- idx: 1455	loss: 4.0508823394775	train score: 15.325	label: 60	prediction: [1]100 [2]65 [3]91 [4]90 [5]26
-- idx: 1460	loss: 4.0330533981323	train score: 15.446666666667	label: 60	prediction: [1]56 [2]49 [3]73 [4]70 [5]24
-- idx: 1465	loss: 4.0190277099609	train score: 15.768333333333	label: 98	prediction: [1]70 [2]71 [3]87 [4]56 [5]22
-- idx: 1470	loss: 4.0660977363586	train score: 15.44	label: 33	prediction: [1]15 [2]92 [3]78 [4]17 [5]48
-- idx: 1475	loss: 4.0492033958435	train score: 16.573333333333	label: 49	prediction: [1]43 [2]49 [3]22 [4]20 [5]19
-- idx: 1480	loss: 4.0443043708801	train score: 15.831666666667	label: 75	prediction: [1]75 [2]74 [3]89 [4]29 [5]55
-- idx: 1485	loss: 4.056957244873	train score: 13.903333333333	label: 91	prediction: [1]91 [2]37 [3]45 [4]79 [5]39
-- idx: 1490	loss: 4.0399622917175	train score: 15.898333333333	label: 65	prediction: [1]99 [2]12 [3]3 [4]71 [5]18
-- idx: 1495	loss: 4.0595321655273	train score: 16.433333333333	label: 75	prediction: [1]75 [2]89 [3]80 [4]28 [5]74
-- current LR: 0.005
-- idx: 1500	loss: 4.0547313690186	train score: 15.626666666667	label: 87	prediction: [1]59 [2]45 [3]90 [4]31 [5]15
-- idx: 1505	loss: 4.0657954216003	train score: 14.67	label: 83	prediction: [1]63 [2]65 [3]31 [4]79 [5]21
-- idx: 1510	loss: 4.0291767120361	train score: 14.785	label: 50	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1515	loss: 4.0501141548157	train score: 15.563333333333	label: 81	prediction: [1]81 [2]28 [3]37 [4]33 [5]40
-- idx: 1520	loss: 4.0375385284424	train score: 14.303333333333	label: 1	prediction: [1]85 [2]84 [3]42 [4]22 [5]49
-- idx: 1525	loss: 4.0270924568176	train score: 13.575	label: 6	prediction: [1]96 [2]92 [3]76 [4]19 [5]34
-- idx: 1530	loss: 4.0307989120483	train score: 14.535	label: 73	prediction: [1]12 [2]38 [3]26 [4]65 [5]23
-- idx: 1535	loss: 4.0554008483887	train score: 14.668333333333	label: 39	prediction: [1]39 [2]65 [3]59 [4]58 [5]45
-- idx: 1540	loss: 4.0533809661865	train score: 14.946666666667	label: 80	prediction: [1]52 [2]2 [3]25 [4]46 [5]89
-- idx: 1545	loss: 4.054181098938	train score: 14.425	label: 7	prediction: [1]51 [2]48 [3]73 [4]56 [5]52
-- idx: 1550	loss: 4.0640454292297	train score: 14.198333333333	label: 53	prediction: [1]53 [2]88 [3]1 [4]72 [5]35
-- idx: 1555	loss: 4.04856300354	train score: 14.218333333333	label: 5	prediction: [1]33 [2]73 [3]20 [4]92 [5]91
-- idx: 1560	loss: 4.0327324867249	train score: 16.015	label: 32	prediction: [1]62 [2]82 [3]88 [4]32 [5]31
-- idx: 1565	loss: 4.0433459281921	train score: 14	label: 54	prediction: [1]37 [2]39 [3]83 [4]82 [5]30
-- idx: 1570	loss: 4.0418033599854	train score: 16.396666666667	label: 43	prediction: [1]26 [2]52 [3]73 [4]22 [5]70
-- idx: 1575	loss: 4.0516805648804	train score: 14.405	label: 49	prediction: [1]43 [2]49 [3]17 [4]29 [5]15
-- idx: 1580	loss: 4.0342030525208	train score: 16.731666666667	label: 61	prediction: [1]71 [2]74 [3]32 [4]38 [5]39
-- idx: 1585	loss: 4.0834851264954	train score: 14.678333333333	label: 1	prediction: [1]93 [2]72 [3]35 [4]27 [5]1
-- idx: 1590	loss: 4.0597772598267	train score: 14.478333333333	label: 99	prediction: [1]100 [2]19 [3]42 [4]26 [5]69
-- idx: 1595	loss: 4.0416007041931	train score: 16.538333333333	label: 24	prediction: [1]15 [2]84 [3]40 [4]33 [5]77
-- idx: 1600	loss: 4.0677914619446	train score: 13.46	label: 7	prediction: [1]41 [2]95 [3]17 [4]48 [5]43
-- idx: 1605	loss: 4.0326228141785	train score: 15.065	label: 1	prediction: [1]85 [2]42 [3]55 [4]27 [5]18
-- idx: 1610	loss: 4.0343437194824	train score: 16.498333333333	label: 55	prediction: [1]34 [2]55 [3]72 [4]78 [5]11
-- idx: 1615	loss: 4.0353412628174	train score: 15.613333333333	label: 25	prediction: [1]55 [2]72 [3]80 [4]25 [5]89
-- idx: 1620	loss: 4.0557198524475	train score: 13.741666666667	label: 26	prediction: [1]42 [2]73 [3]22 [4]98 [5]26
-- idx: 1625	loss: 4.0182437896729	train score: 14.556666666667	label: 17	prediction: [1]38 [2]40 [3]91 [4]33 [5]73
-- idx: 1630	loss: 4.0641121864319	train score: 14.826666666667	label: 85	prediction: [1]85 [2]90 [3]60 [4]64 [5]72
-- idx: 1635	loss: 4.0540494918823	train score: 14.978333333333	label: 93	prediction: [1]16 [2]8 [3]27 [4]49 [5]90
-- idx: 1640	loss: 4.0481176376343	train score: 14.713333333333	label: 12	prediction: [1]69 [2]34 [3]24 [4]84 [5]26
-- idx: 1645	loss: 4.0384635925293	train score: 15.075	label: 52	prediction: [1]19 [2]34 [3]16 [4]17 [5]36
-- idx: 1650	loss: 4.0485615730286	train score: 12.585	label: 52	prediction: [1]26 [2]49 [3]20 [4]69 [5]22
-- idx: 1655	loss: 4.052535533905	train score: 13.57	label: 99	prediction: [1]87 [2]18 [3]20 [4]56 [5]22
-- idx: 1660	loss: 4.0411777496338	train score: 15.123333333333	label: 88	prediction: [1]62 [2]88 [3]91 [4]45 [5]93
-- idx: 1665	loss: 4.0431470870972	train score: 15.123333333333	label: 43	prediction: [1]55 [2]72 [3]27 [4]32 [5]35
-- idx: 1670	loss: 4.0449628829956	train score: 14.416666666667	label: 60	prediction: [1]30 [2]31 [3]83 [4]82 [5]47
-- idx: 1675	loss: 4.0372438430786	train score: 16.043333333333	label: 13	prediction: [1]47 [2]64 [3]37 [4]86 [5]68
-- idx: 1680	loss: 4.0558218955994	train score: 14.486666666667	label: 92	prediction: [1]20 [2]56 [3]69 [4]18 [5]19
-- idx: 1685	loss: 4.0240516662598	train score: 16.831666666667	label: 58	prediction: [1]62 [2]31 [3]79 [4]100 [5]68
-- idx: 1690	loss: 4.0241107940674	train score: 16.848333333333	label: 72	prediction: [1]55 [2]78 [3]32 [4]35 [5]51
-- idx: 1695	loss: 4.033420085907	train score: 15.638333333333	label: 35	prediction: [1]72 [2]76 [3]32 [4]35 [5]51
-- idx: 1700	loss: 4.0407748222351	train score: 16.441666666667	label: 47	prediction: [1]39 [2]65 [3]83 [4]82 [5]30
-- idx: 1705	loss: 4.0334477424622	train score: 15.17	label: 2	prediction: [1]72 [2]25 [3]20 [4]52 [5]89
-- idx: 1710	loss: 4.0444736480713	train score: 16.211666666667	label: 9	prediction: [1]39 [2]76 [3]83 [4]100 [5]31
-- idx: 1715	loss: 4.055513381958	train score: 14.62	label: 41	prediction: [1]29 [2]33 [3]56 [4]69 [5]24
-- idx: 1720	loss: 4.0510210990906	train score: 14.705	label: 81	prediction: [1]82 [2]28 [3]37 [4]83 [5]81
-- idx: 1725	loss: 4.0319223403931	train score: 16.378333333333	label: 16	prediction: [1]44 [2]79 [3]16 [4]92 [5]33
-- idx: 1730	loss: 4.0593013763428	train score: 13.61	label: 87	prediction: [1]36 [2]98 [3]59 [4]26 [5]31
-- idx: 1735	loss: 4.0590133666992	train score: 14.598333333333	label: 17	prediction: [1]77 [2]17 [3]52 [4]40 [5]51
-- idx: 1740	loss: 4.0403032302856	train score: 15.06	label: 94	prediction: [1]94 [2]49 [3]90 [4]27 [5]85
-- idx: 1745	loss: 4.0396676063538	train score: 14.63	label: 56	prediction: [1]14 [2]74 [3]29 [4]38 [5]60
-- idx: 1750	loss: 4.0412812232971	train score: 14.636666666667	label: 60	prediction: [1]52 [2]71 [3]26 [4]34 [5]38
-- idx: 1755	loss: 4.0439038276672	train score: 16.255	label: 76	prediction: [1]100 [2]9 [3]65 [4]23 [5]87
-- idx: 1760	loss: 4.0569858551025	train score: 14.791666666667	label: 23	prediction: [1]9 [2]98 [3]87 [4]100 [5]36
-- idx: 1765	loss: 4.0375075340271	train score: 15.981666666667	label: 37	prediction: [1]39 [2]45 [3]83 [4]31 [5]82
-- idx: 1770	loss: 4.0566382408142	train score: 14.485	label: 14	prediction: [1]74 [2]93 [3]27 [4]32 [5]91
-- idx: 1775	loss: 4.0381083488464	train score: 14.546666666667	label: 70	prediction: [1]18 [2]57 [3]42 [4]69 [5]70
-- idx: 1780	loss: 4.035758972168	train score: 13.846666666667	label: 22	prediction: [1]100 [2]19 [3]42 [4]69 [5]26
-- idx: 1785	loss: 4.0403776168823	train score: 15.035	label: 73	prediction: [1]51 [2]49 [3]29 [4]92 [5]40
-- idx: 1790	loss: 4.0424575805664	train score: 15.405	label: 51	prediction: [1]78 [2]33 [3]44 [4]48 [5]49
-- idx: 1795	loss: 4.0640187263489	train score: 16.265	label: 65	prediction: [1]31 [2]79 [3]94 [4]91 [5]90
-- idx: 1800	loss: 4.0358824729919	train score: 16.416666666667	label: 40	prediction: [1]12 [2]71 [3]40 [4]42 [5]22
-- idx: 1805	loss: 4.0283918380737	train score: 16.816666666667	label: 90	prediction: [1]8 [2]33 [3]48 [4]90 [5]41
-- idx: 1810	loss: 4.0407748222351	train score: 15.101666666667	label: 68	prediction: [1]68 [2]37 [3]30 [4]31 [5]79
-- idx: 1815	loss: 4.0377068519592	train score: 14.375	label: 22	prediction: [1]56 [2]22 [3]18 [4]19 [5]20
-- idx: 1820	loss: 4.0438976287842	train score: 15.336666666667	label: 47	prediction: [1]31 [2]63 [3]82 [4]83 [5]21
-- idx: 1825	loss: 4.0420918464661	train score: 17.113333333333	label: 60	prediction: [1]40 [2]48 [3]92 [4]91 [5]33
-- idx: 1830	loss: 4.0464482307434	train score: 14.171666666667	label: 43	prediction: [1]55 [2]72 [3]27 [4]32 [5]35
-- idx: 1835	loss: 4.0492997169495	train score: 16.155	label: 64	prediction: [1]27 [2]32 [3]35 [4]97 [5]62
-- idx: 1840	loss: 4.0680890083313	train score: 13.995	label: 85	prediction: [1]93 [2]74 [3]27 [4]72 [5]85
-- idx: 1845	loss: 4.042293548584	train score: 14.168333333333	label: 89	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 1850	loss: 4.0481634140015	train score: 15.266666666667	label: 91	prediction: [1]74 [2]47 [3]100 [4]31 [5]79
-- idx: 1855	loss: 4.0370526313782	train score: 17.038333333333	label: 1	prediction: [1]93 [2]32 [3]35 [4]27 [5]1
-- idx: 1860	loss: 4.031608581543	train score: 15.938333333333	label: 46	prediction: [1]72 [2]25 [3]20 [4]52 [5]89
-- idx: 1865	loss: 4.0364899635315	train score: 15.798333333333	label: 18	prediction: [1]47 [2]45 [3]68 [4]54 [5]21
-- idx: 1870	loss: 4.0388975143433	train score: 15.513333333333	label: 14	prediction: [1]41 [2]49 [3]48 [4]84 [5]43
-- idx: 1875	loss: 4.0534319877625	train score: 14.548333333333	label: 89	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1880	loss: 4.0468883514404	train score: 14.848333333333	label: 9	prediction: [1]39 [2]65 [3]36 [4]21 [5]47
-- idx: 1885	loss: 4.0711936950684	train score: 14.701666666667	label: 37	prediction: [1]47 [2]82 [3]62 [4]22 [5]60
-- idx: 1890	loss: 4.0439262390137	train score: 16.223333333333	label: 64	prediction: [1]44 [2]68 [3]83 [4]82 [5]79
-- idx: 1895	loss: 4.0462760925293	train score: 15.183333333333	label: 6	prediction: [1]50 [2]34 [3]22 [4]24 [5]84
-- idx: 1900	loss: 4.0467510223389	train score: 13.036666666667	label: 31	prediction: [1]59 [2]31 [3]21 [4]63 [5]62
-- idx: 1905	loss: 4.0438327789307	train score: 14.686666666667	label: 20	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 1910	loss: 4.049147605896	train score: 14.921666666667	label: 9	prediction: [1]92 [2]17 [3]41 [4]9 [5]95
-- idx: 1915	loss: 4.0496439933777	train score: 14.845	label: 13	prediction: [1]45 [2]47 [3]86 [4]30 [5]83
-- idx: 1920	loss: 4.042359828949	train score: 14.598333333333	label: 44	prediction: [1]86 [2]63 [3]15 [4]36 [5]94
-- idx: 1925	loss: 4.0368189811707	train score: 15.875	label: 82	prediction: [1]13 [2]65 [3]82 [4]21 [5]31
-- idx: 1930	loss: 4.0473203659058	train score: 13.155	label: 72	prediction: [1]55 [2]76 [3]27 [4]32 [5]35
-- idx: 1935	loss: 4.0462107658386	train score: 13.37	label: 73	prediction: [1]84 [2]10 [3]18 [4]57 [5]74
-- idx: 1940	loss: 4.02783203125	train score: 14.548333333333	label: 96	prediction: [1]51 [2]17 [3]78 [4]43 [5]20
-- idx: 1945	loss: 4.033082485199	train score: 14.59	label: 34	prediction: [1]18 [2]57 [3]42 [4]69 [5]70
-- idx: 1950	loss: 4.0605864524841	train score: 15.536666666667	label: 27	prediction: [1]64 [2]27 [3]35 [4]93 [5]88
-- idx: 1955	loss: 4.044780254364	train score: 13.753333333333	label: 28	prediction: [1]75 [2]28 [3]93 [4]64 [5]81
-- idx: 1960	loss: 4.052586555481	train score: 14.553333333333	label: 87	prediction: [1]79 [2]37 [3]26 [4]83 [5]82
-- idx: 1965	loss: 4.0573434829712	train score: 15.136666666667	label: 84	prediction: [1]10 [2]70 [3]84 [4]60 [5]54
-- idx: 1970	loss: 4.0485925674438	train score: 15.231666666667	label: 100	prediction: [1]42 [2]60 [3]22 [4]24 [5]26
-- idx: 1975	loss: 4.0431699752808	train score: 15.28	label: 38	prediction: [1]52 [2]71 [3]26 [4]34 [5]38
-- idx: 1980	loss: 4.0218229293823	train score: 14.84	label: 8	prediction: [1]95 [2]48 [3]92 [4]52 [5]51
-- idx: 1985	loss: 4.0481286048889	train score: 15.288333333333	label: 47	prediction: [1]39 [2]47 [3]83 [4]82 [5]31
-- idx: 1990	loss: 4.0576062202454	train score: 14.51	label: 49	prediction: [1]20 [2]56 [3]50 [4]18 [5]19
-- idx: 1995	loss: 4.0272212028503	train score: 13.885	label: 88	prediction: [1]64 [2]85 [3]74 [4]32 [5]67
-- idx: 2000	loss: 4.0462369918823	train score: 14.66	label: 9	prediction: [1]22 [2]76 [3]6 [4]26 [5]12
-- idx: 2005	loss: 4.0227890014648	train score: 15.861666666667	label: 59	prediction: [1]36 [2]26 [3]87 [4]38 [5]23
-- idx: 2010	loss: 4.0537095069885	train score: 15.686666666667	label: 16	prediction: [1]92 [2]44 [3]24 [4]33 [5]36
-- idx: 2015	loss: 4.0362477302551	train score: 14.606666666667	label: 18	prediction: [1]78 [2]49 [3]18 [4]17 [5]14
-- idx: 2020	loss: 4.019898891449	train score: 15.391666666667	label: 38	prediction: [1]34 [2]52 [3]22 [4]84 [5]56
-- idx: 2025	loss: 4.0285792350769	train score: 14.585	label: 50	prediction: [1]33 [2]60 [3]24 [4]78 [5]77
-- idx: 2030	loss: 4.0328154563904	train score: 15.95	label: 7	prediction: [1]60 [2]77 [3]92 [4]91 [5]33
-- idx: 2035	loss: 4.0479602813721	train score: 14.966666666667	label: 25	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 2040	loss: 4.0310673713684	train score: 15.226666666667	label: 54	prediction: [1]59 [2]58 [3]21 [4]37 [5]30
-- idx: 2045	loss: 4.0391530990601	train score: 15.948333333333	label: 25	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 2050	loss: 4.0549960136414	train score: 13.148333333333	label: 77	prediction: [1]42 [2]78 [3]92 [4]33 [5]34
-- idx: 2055	loss: 4.0569839477539	train score: 14.585	label: 46	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 2060	loss: 4.0443739891052	train score: 15.308333333333	label: 11	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 2065	loss: 4.0717306137085	train score: 15.441666666667	label: 89	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 2070	loss: 4.0347542762756	train score: 14.611666666667	label: 5	prediction: [1]40 [2]15 [3]92 [4]36 [5]95
-- idx: 2075	loss: 4.0670919418335	train score: 14.09	label: 67	prediction: [1]45 [2]86 [3]67 [4]66 [5]21
-- idx: 2080	loss: 4.043637752533	train score: 15.443333333333	label: 84	prediction: [1]87 [2]57 [3]42 [4]69 [5]38
-- idx: 2085	loss: 4.0426197052002	train score: 13.688333333333	label: 1	prediction: [1]93 [2]34 [3]18 [4]1 [5]74
-- idx: 2090	loss: 4.0479044914246	train score: 15.741666666667	label: 20	prediction: [1]44 [2]43 [3]17 [4]92 [5]48
-- idx: 2095	loss: 4.0339407920837	train score: 14.991666666667	label: 89	prediction: [1]50 [2]72 [3]20 [4]80 [5]25
-- idx: 2100	loss: 4.0628609657288	train score: 14.555	label: 41	prediction: [1]49 [2]51 [3]29 [4]34 [5]40
-- idx: 2105	loss: 4.0569262504578	train score: 15.83	label: 77	prediction: [1]49 [2]14 [3]52 [4]78 [5]33
-- idx: 2110	loss: 4.0373072624207	train score: 16.036666666667	label: 61	prediction: [1]30 [2]61 [3]21 [4]45 [5]82
-- idx: 2115	loss: 4.0477895736694	train score: 14.55	label: 64	prediction: [1]21 [2]32 [3]97 [4]74 [5]91
-- idx: 2120	loss: 4.0267157554626	train score: 15.851666666667	label: 60	prediction: [1]48 [2]44 [3]60 [4]92 [5]51
-- idx: 2125	loss: 4.0578627586365	train score: 14.683333333333	label: 31	prediction: [1]79 [2]44 [3]86 [4]83 [5]82
-- idx: 2130	loss: 4.0261607170105	train score: 15.216666666667	label: 79	prediction: [1]79 [2]37 [3]86 [4]83 [5]82
-- idx: 2135	loss: 4.0491952896118	train score: 15.73	label: 45	prediction: [1]68 [2]65 [3]79 [4]31 [5]86
-- idx: 2140	loss: 4.0436310768127	train score: 14.85	label: 5	prediction: [1]11 [2]27 [3]33 [4]35 [5]56
-- idx: 2145	loss: 4.0687022209167	train score: 14.863333333333	label: 11	prediction: [1]88 [2]32 [3]81 [4]67 [5]66
-- idx: 2150	loss: 4.033299446106	train score: 15.746666666667	label: 30	prediction: [1]45 [2]47 [3]86 [4]83 [5]82
-- idx: 2155	loss: 4.0272064208984	train score: 14.941666666667	label: 88	prediction: [1]53 [2]88 [3]72 [4]1 [5]35
-- idx: 2160	loss: 4.0496830940247	train score: 15.173333333333	label: 96	prediction: [1]24 [2]48 [3]19 [4]20 [5]22
-- idx: 2165	loss: 4.0727214813232	train score: 14.508333333333	label: 43	prediction: [1]92 [2]8 [3]95 [4]33 [5]51
-- idx: 2170	loss: 4.0424332618713	train score: 13.918333333333	label: 65	prediction: [1]10 [2]9 [3]100 [4]76 [5]36
-- idx: 2175	loss: 4.0415296554565	train score: 15.783333333333	label: 16	prediction: [1]43 [2]69 [3]22 [4]24 [5]34
-- idx: 2180	loss: 4.0422344207764	train score: 15.356666666667	label: 1	prediction: [1]53 [2]88 [3]72 [4]1 [5]35
-- idx: 2185	loss: 4.0397839546204	train score: 14.333333333333	label: 100	prediction: [1]43 [2]41 [3]49 [4]48 [5]44
-- idx: 2190	loss: 4.050507068634	train score: 15.768333333333	label: 92	prediction: [1]92 [2]38 [3]71 [4]29 [5]73
-- ...
-- idx: 29290	loss: 4.0584087371826	train score: 15.201666666667	label: 7	prediction: [1]7 [2]17 [3]73 [4]16 [5]8
-- idx: 29295	loss: 4.0504403114319	train score: 14.321666666667	label: 38	prediction: [1]10 [2]94 [3]74 [4]91 [5]11
-- idx: 29300	loss: 4.0225524902344	train score: 16.211666666667	label: 12	prediction: [1]65 [2]63 [3]21 [4]82 [5]30
-- idx: 29305	loss: 4.040497303009	train score: 15.333333333333	label: 81	prediction: [1]68 [2]54 [3]82 [4]63 [5]79
-- idx: 29310	loss: 4.0412101745605	train score: 15.506666666667	label: 9	prediction: [1]73 [2]9 [3]43 [4]15 [5]14
-- idx: 29315	loss: 4.033305644989	train score: 15.24	label: 17	prediction: [1]95 [2]34 [3]60 [4]19 [5]20
-- idx: 29320	loss: 4.0525789260864	train score: 16.273333333333	label: 65	prediction: [1]65 [2]100 [3]62 [4]39 [5]82
-- idx: 29325	loss: 4.0510158538818	train score: 15.325	label: 5	prediction: [1]40 [2]5 [3]73 [4]14 [5]50
-- idx: 29330	loss: 4.0389761924744	train score: 14.516666666667	label: 8	prediction: [1]61 [2]60 [3]78 [4]77 [5]29
-- idx: 29335	loss: 4.0506496429443	train score: 13.603333333333	label: 14	prediction: [1]34 [2]78 [3]24 [4]92 [5]17
-- idx: 29340	loss: 4.0281991958618	train score: 15.785	label: 64	prediction: [1]64 [2]33 [3]44 [4]62 [5]8
-- idx: 29345	loss: 4.0455317497253	train score: 13.368333333333	label: 42	prediction: [1]87 [2]18 [3]69 [4]70 [5]71
-- idx: 29350	loss: 4.0480823516846	train score: 14.96	label: 63	prediction: [1]62 [2]13 [3]37 [4]63 [5]58
-- idx: 29355	loss: 4.0270090103149	train score: 15.125	label: 14	prediction: [1]48 [2]29 [3]73 [4]77 [5]51
-- idx: 29360	loss: 4.0223917961121	train score: 15.2	label: 12	prediction: [1]36 [2]65 [3]26 [4]90 [5]30
-- idx: 29365	loss: 4.0483336448669	train score: 15.175	label: 12	prediction: [1]14 [2]40 [3]49 [4]7 [5]51
-- idx: 29370	loss: 4.0229902267456	train score: 17.818333333333	label: 75	prediction: [1]75 [2]28 [3]29 [4]37 [5]70
-- idx: 29375	loss: 4.0482821464539	train score: 15.456666666667	label: 89	prediction: [1]82 [2]21 [3]31 [4]37 [5]44
-- idx: 29380	loss: 4.035572052002	train score: 14.663333333333	label: 7	prediction: [1]86 [2]59 [3]100 [4]37 [5]83
-- idx: 29385	loss: 4.0402297973633	train score: 15.698333333333	label: 24	prediction: [1]92 [2]24 [3]51 [4]44 [5]43
-- idx: 29390	loss: 4.0359477996826	train score: 13.878333333333	label: 90	prediction: [1]11 [2]51 [3]29 [4]24 [5]32
-- idx: 29395	loss: 4.0539307594299	train score: 15.115	label: 24	prediction: [1]11 [2]55 [3]35 [4]43 [5]17
-- idx: 29400	loss: 4.0461378097534	train score: 13.583333333333	label: 10	prediction: [1]26 [2]44 [3]21 [4]23 [5]54
-- idx: 29405	loss: 4.046012878418	train score: 15.898333333333	label: 30	prediction: [1]30 [2]38 [3]22 [4]12 [5]26
-- idx: 29410	loss: 4.0420236587524	train score: 14.413333333333	label: 23	prediction: [1]94 [2]44 [3]39 [4]23 [5]87
-- idx: 29415	loss: 4.0289311408997	train score: 16.08	label: 60	prediction: [1]91 [2]29 [3]65 [4]19 [5]96
-- idx: 29420	loss: 4.044177532196	train score: 15.981666666667	label: 39	prediction: [1]39 [2]47 [3]83 [4]82 [5]31
-- idx: 29425	loss: 4.0304942131042	train score: 15.123333333333	label: 22	prediction: [1]20 [2]22 [3]17 [4]18 [5]19
-- idx: 29430	loss: 4.0523419380188	train score: 13.653333333333	label: 6	prediction: [1]44 [2]12 [3]23 [4]76 [5]21
-- idx: 29435	loss: 4.035861492157	train score: 15.905	label: 35	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 29440	loss: 4.0345935821533	train score: 14.876666666667	label: 18	prediction: [1]72 [2]32 [3]11 [4]18 [5]24
-- idx: 29445	loss: 4.0537519454956	train score: 13.536666666667	label: 19	prediction: [1]96 [2]10 [3]19 [4]14 [5]90
-- idx: 29450	loss: 4.0435452461243	train score: 14.696666666667	label: 5	prediction: [1]95 [2]51 [3]33 [4]73 [5]17
-- idx: 29455	loss: 4.044252872467	train score: 14.723333333333	label: 17	prediction: [1]30 [2]76 [3]82 [4]12 [5]62
-- idx: 29460	loss: 4.0492568016052	train score: 15.261666666667	label: 62	prediction: [1]83 [2]39 [3]62 [4]21 [5]37
-- idx: 29465	loss: 4.0334024429321	train score: 15.31	label: 86	prediction: [1]68 [2]45 [3]83 [4]82 [5]31
-- idx: 29470	loss: 4.0504932403564	train score: 14.861666666667	label: 31	prediction: [1]45 [2]31 [3]86 [4]82 [5]94
-- idx: 29475	loss: 4.0520443916321	train score: 15.038333333333	label: 35	prediction: [1]27 [2]97 [3]85 [4]35 [5]55
-- idx: 29480	loss: 4.040177822113	train score: 14.005	label: 47	prediction: [1]100 [2]69 [3]19 [4]34 [5]38
-- idx: 29485	loss: 4.0442276000977	train score: 14.473333333333	label: 83	prediction: [1]90 [2]82 [3]76 [4]31 [5]83
-- idx: 29490	loss: 4.0281643867493	train score: 14.518333333333	label: 68	prediction: [1]82 [2]86 [3]31 [4]83 [5]37
-- idx: 29495	loss: 4.0564665794373	train score: 14.11	label: 83	prediction: [1]37 [2]44 [3]83 [4]82 [5]31
-- idx: 29500	loss: 4.0560927391052	train score: 14.961666666667	label: 15	prediction: [1]40 [2]95 [3]15 [4]92 [5]91
-- idx: 29505	loss: 4.0322141647339	train score: 15.046666666667	label: 97	prediction: [1]11 [2]27 [3]72 [4]35 [5]74
-- idx: 29510	loss: 4.0378031730652	train score: 14.356666666667	label: 52	prediction: [1]40 [2]41 [3]84 [4]73 [5]29
-- idx: 29515	loss: 4.0505566596985	train score: 16.393333333333	label: 29	prediction: [1]33 [2]73 [3]20 [4]14 [5]22
-- idx: 29520	loss: 4.0469579696655	train score: 16.256666666667	label: 45	prediction: [1]49 [2]48 [3]61 [4]24 [5]51
-- idx: 29525	loss: 4.046498298645	train score: 15.166666666667	label: 92	prediction: [1]26 [2]27 [3]91 [4]45 [5]87
-- idx: 29530	loss: 4.055079460144	train score: 14.033333333333	label: 83	prediction: [1]82 [2]83 [3]30 [4]37 [5]79
-- idx: 29535	loss: 4.0454363822937	train score: 16.066666666667	label: 34	prediction: [1]78 [2]50 [3]20 [4]22 [5]24
-- idx: 29540	loss: 4.048999786377	train score: 14.445	label: 71	prediction: [1]87 [2]57 [3]42 [4]69 [5]38
-- idx: 29545	loss: 4.0246949195862	train score: 15.16	label: 50	prediction: [1]14 [2]29 [3]51 [4]44 [5]40
-- idx: 29550	loss: 4.0209078788757	train score: 15.235	label: 20	prediction: [1]38 [2]41 [3]20 [4]22 [5]84
-- idx: 29555	loss: 4.0468230247498	train score: 16.115	label: 53	prediction: [1]53 [2]67 [3]66 [4]88 [5]44
-- idx: 29560	loss: 4.0316205024719	train score: 15.636666666667	label: 72	prediction: [1]89 [2]52 [3]2 [4]46 [5]72
-- idx: 29565	loss: 4.0333003997803	train score: 15.346666666667	label: 88	prediction: [1]11 [2]27 [3]72 [4]35 [5]74
-- idx: 29570	loss: 4.0260310173035	train score: 15.685	label: 92	prediction: [1]73 [2]51 [3]91 [4]17 [5]78
-- idx: 29575	loss: 4.0323195457458	train score: 16.241666666667	label: 94
-- prediction: [1]82 [2]47 [3]30 [4]31 [5]100
-- idx: 29580	loss: 4.0532655715942	train score: 13.716666666667	label: 95	prediction: [1]98 [2]71 [3]42 [4]84 [5]57
-- idx: 29585	loss: 4.0280532836914	train score: 15.941666666667	label: 33	prediction: [1]15 [2]48 [3]51 [4]43 [5]41
-- idx: 29590	loss: 4.0405769348145	train score: 15.995	label: 53	prediction: [1]32 [2]93 [3]81 [4]53 [5]88
-- idx: 29595	loss: 4.0482587814331
-- train score: 14.993333333333	label: 45	prediction: [1]79 [2]47 [3]86 [4]30 [5]31
-- idx: 29600	loss: 4.0335450172424	train score: 15.156666666667	label: 88	prediction: [1]8 [2]87 [3]35 [4]11 [5]81
-- idx: 29605	loss: 4.0361285209656	train score: 16.103333333333	label: 88	prediction: [1]53 [2]88 [3]72 [4]1 [5]35
-- idx: 29610	loss: 4.0272974967957	train score: 14.868333333333	label: 72	prediction: [1]52 [2]55 [3]80 [4]72 [5]85
-- idx: 29615	loss: 4.0408363342285	train score: 16.848333333333	label: 85	prediction: [1]1 [2]74 [3]93 [4]85 [5]26
-- idx: 29620	loss: 4.0448822975159	train score: 14.258333333333	label: 34
-- prediction: [1]52 [2]34 [3]92 [4]73 [5]24
-- idx: 29625	loss: 4.0439686775208	train score: 14.923333333333	label: 39	prediction: [1]83 [2]45 [3]31 [4]62 [5]26
-- idx: 29630	loss: 4.0608654022217	train score: 15.071666666667	label: 94	prediction: [1]30 [2]37 [3]21 [4]83 [5]82
-- idx: 29635	loss: 4.0533790588379	train score: 14.55	label: 95	prediction: [1]15 [2]92 [3]41 [4]40 [5]33
-- idx: 29640	loss: 4.0548558235168	train score: 15.995	label: 31	prediction: [1]31 [2]54 [3]68 [4]59 [5]86
-- idx: 29645	loss: 4.0425310134888	train score: 15.23	label: 69	prediction: [1]87 [2]57 [3]42 [4]69 [5]38
-- idx: 29650	loss: 4.0417413711548	train score: 15.046666666667	label: 13	prediction: [1]47 [2]68 [3]30 [4]31 [5]82
-- idx: 29655	loss: 4.0292615890503	train score: 15.425	label: 6	prediction: [1]29 [2]31 [3]91 [4]90 [5]26
-- idx: 29660	loss: 4.0241250991821	train score: 15.538333333333	label: 84	prediction: [1]12 [2]30 [3]61 [4]69 [5]13
-- idx: 29665	loss: 4.0385642051697
-- train score: 15.685	label: 43	prediction: [1]51 [2]49 [3]78 [4]52 [5]33
-- idx: 29670	loss: 4.0355019569397	train score: 15.676666666667	label: 75	prediction: [1]75 [2]28 [3]29 [4]37 [5]70
-- idx: 29675	loss: 4.0668468475342	train score: 14.111666666667	label: 40	prediction: [1]73 [2]33 [3]16 [4]14 [5]94
-- idx: 29680	loss: 4.0506711006165	train score: 14.586666666667	label: 31	prediction: [1]31 [2]61 [3]64 [4]63 [5]62
-- idx: 29685	loss: 4.0494999885559	train score: 14.768333333333	label: 91	prediction: [1]91 [2]71 [3]35 [4]22 [5]84
-- idx: 29690	loss: 4.0251955986023	train score: 15.353333333333	label: 78	prediction: [1]40 [2]43 [3]29 [4]92 [5]32
-- idx: 29695	loss: 4.0570750236511	train score: 15.375	label: 10	prediction: [1]37 [2]47 [3]82 [4]30 [5]31
-- idx: 29700	loss: 4.0477232933044	train score: 14.99	label: 27	prediction: [1]72 [2]11 [3]40 [4]80 [5]74
-- idx: 29705	loss: 4.0359706878662	train score: 14.956666666667	label: 92	prediction: [1]73 [2]41 [3]29 [4]84 [5]78
-- idx: 29710	loss: 4.0434560775757	train score: 14.456666666667	label: 12	prediction: [1]68 [2]47 [3]83 [4]82 [5]30
-- idx: 29715	loss: 4.0462021827698	train score: 15.018333333333	label: 37	prediction: [1]31 [2]59 [3]64 [4]63 [5]62
-- idx: 29720	loss: 4.0364503860474	train score: 17.241666666667	label: 100	prediction: [1]44 [2]47 [3]100 [4]82 [5]37
-- idx: 29725	loss: 4.0324521064758	train score: 15.625	label: 32	prediction: [1]33 [2]72 [3]11 [4]51 [5]35
-- idx: 29730	loss: 4.0395903587341	train score: 14.733333333333	label: 40	prediction: [1]95 [2]40 [3]17 [4]96 [5]19
-- idx: 29735	loss: 4.0516138076782	train score: 15.433333333333	label: 46	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 29740	loss: 4.0516304969788	train score: 16.411666666667	label: 59	prediction: [1]65 [2]63 [3]86 [4]68 [5]37
-- idx: 29745	loss: 4.0441446304321	train score: 15.818333333333	label: 7	prediction: [1]14 [2]51 [3]92 [4]29 [5]90
-- idx: 29750	loss: 4.0484690666199	train score: 16.975	label: 89	prediction: [1]72 [2]25 [3]20 [4]52 [5]89
-- idx: 29755	loss: 4.0267715454102	train score: 15.01	label: 17	prediction: [1]84 [2]38 [3]24 [4]29 [5]73
-- idx: 29760	loss: 4.0778665542603	train score: 16.01	label: 28	prediction: [1]28 [2]85 [3]97 [4]75 [5]2
-- idx: 29765	loss: 4.035801410675	train score: 15.12	label: 23	prediction: [1]87 [2]44 [3]65 [4]91 [5]23
-- idx: 29770	loss: 4.0285973548889	train score: 17.92	label: 27	prediction: [1]85 [2]82 [3]27 [4]62 [5]93
-- idx: 29775	loss: 4.0264945030212	train score: 17.011666666667	label: 84	prediction: [1]14 [2]49 [3]43 [4]41 [5]51
-- idx: 29780	loss: 4.0322599411011	train score: 16.238333333333	label: 15	prediction: [1]43 [2]8 [3]15 [4]48 [5]52
-- idx: 29785	loss: 4.0523467063904	train score: 15.648333333333	label: 96	prediction: [1]59 [2]98 [3]87 [4]76 [5]36
-- idx: 29790	loss: 4.0422506332397	train score: 14.238333333333	label: 75	prediction: [1]75 [2]28 [3]29 [4]67 [5]65
-- idx: 29795	loss: 4.0333914756775	train score: 14.66	label: 1	prediction: [1]67 [2]66 [3]74 [4]85 [5]87
-- idx: 29800	loss: 4.049861907959	train score: 15.885	label: 47	prediction: [1]65 [2]37 [3]30 [4]31 [5]68
-- idx: 29805	loss: 4.0581269264221	train score: 15.443333333333	label: 45	prediction: [1]33 [2]92 [3]60 [4]77 [5]52
-- idx: 29810	loss: 4.043158531189	train score: 15.498333333333	label: 79	prediction: [1]79 [2]58 [3]30 [4]31 [5]83
-- idx: 29815	loss: 4.0602669715881	train score: 13.555	label: 87	prediction: [1]86 [2]79 [3]94 [4]61 [5]87
-- idx: 29820	loss: 4.0513806343079	train score: 14.558333333333	label: 86	prediction: [1]39 [2]68 [3]83 [4]82 [5]30
-- idx: 29825	loss: 4.0369839668274	train score: 15.786666666667	label: 29	prediction: [1]71 [2]74 [3]38 [4]40 [5]41
-- idx: 29830	loss: 4.0357780456543	train score: 16.278333333333	label: 95	prediction: [1]49 [2]73 [3]91 [4]11 [5]84
-- idx: 29835	loss: 4.0578479766846	train score: 16.271666666667	label: 59	prediction: [1]62 [2]63 [3]82 [4]68 [5]86
-- idx: 29840	loss: 4.0666861534119	train score: 14.613333333333	label: 4	prediction: [1]31 [2]39 [3]21 [4]83 [5]82
-- idx: 29845	loss: 4.0448217391968	train score: 15.2	label: 40	prediction: [1]51 [2]8 [3]49 [4]43 [5]41
-- idx: 29850	loss: 4.0467038154602	train score: 14.613333333333	label: 4	prediction: [1]42 [2]98 [3]22 [4]56 [5]57
-- idx: 29855	loss: 4.0480546951294	train score: 13.311666666667	label: 36	prediction: [1]48 [2]36 [3]92 [4]8 [5]43
-- idx: 29860	loss: 4.0517063140869	train score: 14.826666666667	label: 48	prediction: [1]43 [2]92 [3]49 [4]48 [5]33
-- idx: 29865	loss: 4.055103302002	train score: 14.791666666667	label: 13	prediction: [1]45 [2]68 [3]21 [4]82 [5]79
-- idx: 29870	loss: 4.0451064109802	train score: 14.251666666667	label: 68	prediction: [1]79 [2]45 [3]86 [4]83 [5]26
-- idx: 29875	loss: 4.0455441474915	train score: 16.443333333333	label: 48	prediction: [1]69 [2]33 [3]92 [4]78 [5]77
-- idx: 29880	loss: 4.0484142303467	train score: 15.111666666667	label: 28	prediction: [1]28 [2]85 [3]97 [4]75 [5]2
-- idx: 29885	loss: 4.0188388824463	train score: 15.706666666667	label: 14	prediction: [1]32 [2]48 [3]84 [4]16 [5]91
-- idx: 29890	loss: 4.0470671653748	train score: 14.233333333333	label: 74	prediction: [1]73 [2]12 [3]21 [4]94 [5]33
-- idx: 29895	loss: 4.0365571975708	train score: 14.178333333333	label: 65	prediction: [1]12 [2]90 [3]60 [4]30 [5]69
-- idx: 29900	loss: 4.05588722229	train score: 16.463333333333	label: 89	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 29905	loss: 4.0243277549744	train score: 16.573333333333	label: 24	prediction: [1]52 [2]69 [3]34 [4]40 [5]41
-- idx: 29910	loss: 4.046000957489	train score: 18.028333333333	label: 5	prediction: [1]5 [2]73 [3]40 [4]78 [5]50
-- idx: 29915	loss: 4.0394530296326	train score: 15.355	label: 85	prediction: [1]72 [2]46 [3]20 [4]52 [5]89
-- idx: 29920	loss: 4.0323328971863	train score: 15.275	label: 65	prediction: [1]39 [2]65 [3]62 [4]31 [5]86
-- idx: 29925	loss: 4.0376076698303	train score: 14.018333333333	label: 92	prediction: [1]48 [2]92 [3]17 [4]15 [5]77
-- idx: 29930	loss: 4.0613250732422	train score: 14	label: 86	prediction: [1]30 [2]31 [3]60 [4]59 [5]63
-- idx: 29935	loss: 4.0260095596313	train score: 13.525	label: 39	prediction: [1]79 [2]45 [3]31 [4]82 [5]37
-- idx: 29940	loss: 4.0195279121399	train score: 16.338333333333	label: 44	prediction: [1]37 [2]44 [3]21 [4]83 [5]82
-- idx: 29945	loss: 4.0706100463867	train score: 13.336666666667	label: 49	prediction: [1]77 [2]43 [3]17 [4]92 [5]33
-- idx: 29950	loss: 4.0364847183228	train score: 15.546666666667	label: 27	prediction: [1]72 [2]85 [3]35 [4]43 [5]49
-- idx: 29955
-- loss: 4.0517191886902	train score: 14.22	label: 91	prediction: [1]59 [2]30 [3]68 [4]21 [5]63
-- idx: 29960	loss: 4.0632061958313	train score: 13.05	label: 58	prediction: [1]31 [2]59 [3]54 [4]21 [5]79
-- idx: 29965	loss: 4.0382943153381	train score: 14.411666666667	label: 85	prediction: [1]10 [2]84 [3]20 [4]18 [5]42
-- idx: 29970	loss: 4.0383172035217	train score: 15.676666666667	label: 45	prediction: [1]91 [2]87 [3]45 [4]23 [5]68
-- idx: 29975	loss: 4.0338129997253	train score: 16.381666666667	label: 87	prediction: [1]76 [2]45 [3]26 [4]83 [5]82
-- idx: 29980	loss: 4.0215239524841	train score: 16.406666666667	label: 10	prediction: [1]73 [2]29 [3]3 [4]22 [5]5
-- idx: 29985	loss: 4.0434889793396	train score: 14.291666666667	label: 68	prediction: [1]30 [2]31 [3]21 [4]68 [5]63
-- idx: 29990	loss: 4.0520315170288	train score: 14.071666666667	label: 1	prediction: [1]45 [2]74 [3]90 [4]91 [5]64
-- idx: 29995	loss: 4.0629014968872	train score: 14.373333333333	label: 50	prediction: [1]14 [2]73 [3]20 [4]19 [5]18
-- current LR: 9.5367431640625e-09
-- idx: 30000	loss: 4.0485739707947	train score: 15.728333333333	label: 23	prediction: [1]44 [2]45 [3]21 [4]31 [5]82
